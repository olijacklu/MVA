# %% [markdown]
# **TP5 DL in practice**
#
# **Authors:**
#
# - Carlos CUEVAS VILLARMIN
# - Oliver JACK
# - Javier Alejandro LOPETEGUI GONZALEZ
#
# *MVA, ENS Paris-Saclay*

# %% [markdown]
# # Koopman operator learning, a toy case: Duffing oscillator
#
# **-- PLEASE SUBMIT YOUR COMPLETED NOTEBOOK WITH CELL OUTPUTS --**

# %% [markdown]
# The aim of this notebook is to describe the dynamics of a non-linear dynamical system by means of the Koopman theory.
#
# ## Introduction
#
# We consider a quantity $x \in \mathbb{R}^n$ (a vector) which evolves with time, following a dynamical system. Think for example of the joint location of the planets in our solar system, which follows the law of gravitation.
#
# Formally, given an initial state $x(t=0) \in \mathbb{R}^n$ at time $t=0$, the time evolution of $x$ is governed by the following dynamical system:
# $$
# \dot{x}(t) = f(x(t)) \quad \text(1)
# $$
#
# where $\dot{x}(t) := \frac{dx(t)}{dt}$ is the temporal derivative, and $f:\mathbb{R}^n \rightarrow \mathbb{R}^n$ is a given map describing the dynamics.
#
# For a given $f$, it is not always possible to solve the differential equation (1) analytically. For this reason, instead, numerical schemes are usually employed, to integrate in time $t$ the equation (1), so as to propagate the initial condition $x(0)$ up to a desired time $T$; think of $x(T) = x(0) + \int_{t=0}^{T} f(x(t)) dt$. The discretization in time of eq (1) or of the integral introduces numerical approximations, and yields estimates of $x(T)$ of various quality depending on the discretization scheme.
#
# In the field of numerical simulations, discretization schemes have been studied for a long time, and numerical solvers already exist to provide good estimates of integrals (far better than with the naive discretization $x_{k+\delta} = x_k + \delta\,f(x_k)$ for a discrete time increment $\delta$, which induces a $O(\delta^2)$ error at each time step).
#
# The goal of this practical session is to make use of such numerical solvers to improve the learning of dynamical systems with neural networks.

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import sys
from tqdm import tqdm

from torch.utils.data import TensorDataset, DataLoader
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.autograd as autograd

# arrange the dataset
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Duffing oscillator
#
# As a toy example, we consider the Duffing oscillator, where the state $x = (x_1, x_2) \in \mathbb{R}^2$ follows the dynamical system described by the following ODEs:
#
# $$
# \dot{x}_1 = x_2\\
# \dot{x}_2 = x_1 - x_1^3
# $$
#
# To integrate in time the ODEs, a 4th order Runge-Kutta scheme can be used.

# %%
def duffing(array_x: np.ndarray) -> np.ndarray:
    array_dx = np.zeros(array_x.shape)
    array_dx[0] = array_x[1]
    array_dx[1] = array_x[0] - array_x[0] ** 3
    return array_dx

# %%
t_max = 500  # Time-horizon integration
n_iter = 5000  # Number of time steps integration
n_initial_conditions = 60  # Number of initial conditions

dim_system = 2

# Generate initial conditions
matrix_x0 = (np.random.rand(n_initial_conditions, dim_system) - 0.5) * 4
array_t = np.linspace(0, t_max, n_iter)
array3d_xt = np.zeros((matrix_x0.shape[0], matrix_x0.shape[1], n_iter))

for i in tqdm(range(matrix_x0.shape[0])):
    # Lambda function is used as solve_ivp requires a function of the form f(t, x)
    ode_result = solve_ivp(lambda _t, array_x: duffing(array_x),
                           [0, t_max],
                           matrix_x0[i],
                           method='RK45',
                           t_eval=array_t)

    array3d_xt[i, :] = ode_result.y
# Out:
# 100%|██████████| 60/60 [00:26<00:00,  2.24it/s]

# %% [markdown]
# The following plot shows trajectories for different initial conditions:

# %%
fig = plt.figure(figsize=(20, 5))
ax = fig.add_subplot(131)
cm = plt.get_cmap("tab10")
print(cm)
for i in range(10):
    ax.plot(array3d_xt[i, 0, :], array3d_xt[i, 1, :], lw=0.5, color=cm(i))
    ax.plot(array3d_xt[i, 0, 0], array3d_xt[i, 1, 0], 'o', lw=1.5, color=cm(i))  #initial condition
ax.set_xlabel('$x_1$', fontsize=20)
ax.set_ylabel('$x_2$', fontsize=20)
plt.show()
# Out:
# <matplotlib.colors.ListedColormap object at 0x7c16a0d99900>

# %% [markdown]
# ## The Koopman operator
# ### Discontinuous in time case
# Given the discrete non-linear dynamical system
#
# $$
# x_{k+1} = F(x_k)
# $$
#
# where $F$ might be the $\delta$-discretised flow map of the continuous dynamical system in eq (1) given by
#
# $$
# x_{k+1} = F(x_k) := x_k + \int_{k}^{k + \delta} f(x(s))ds
# $$
#
# and $X = (x_k)_{k = 0}^N$ the discrete time series of the system state.
#
#
# The _Koopman_ theory states that there exists an infinite-dimensional linear operator $\mathcal{K}$ that advances in time all observable functions $(g_i)_{i = 1}^m$ given by $g_i: \mathbb{R}^n \rightarrow \mathbb{R}$
#
# $$
# \mathcal{K} g_i(x) = g_i \circ F(x)
# $$
#
# This way, the non-linear dynamics of $x$, described by $F$, can be turned into a **linear** dynamical system, described by $\mathcal{K}$, acting on another representation space, formed by the observable quantities $g_i(x)$.
#
# Indeed, let $g_i$ be an observable function and denoting ${g_i}_k := g_i(x_k)$, using the previous equation, the time evolution of the observables is given by
#
# $$
# {g_i}_{k+1} = g_i(x_{k+1}) = g_i(F(x_k)) = g_i \circ F(x_k) = \mathcal{K} g_i(x_k) = \mathcal{K} {g_i}_k
# $$
#
# then, the linearised dynamics of the observables is given by the following equation
#
# $$
# {g_i}_{k+1} = \mathcal{K} {g_i}_k
# $$
#
#
# It is then sufficient to find a function $g: \mathbb{R}^n \rightarrow \mathbb{R}^m$ with $m \gg n$ that embeds the state $x$ into a "larger enough" dimensional space $m$ such that the linear operator $\mathcal{K}$ can be inferred by a matrix $\mathbf{K} \in \mathbb{R}^{m \times m}$.
#
# To project back the dynamics from the Koopman space ($\mathbb{R}^m$, where $g(x)$ lives) to the phase space ($\mathbb{R}^n$, where $x$ lives), a supplementary function $\varphi: \mathbb{R}^m \rightarrow \mathbb{R}^n$ is needed. Going from $x$ to the Koopman space and back yields $\varphi \text{ o  } g = $ Id.
#
# Under this condition, the functions $g$, $\varphi$ and $\mathbf{K}$ can be parametrized $g_{\theta}$, $\varphi_{\rho}$ and $\mathbf{K}_{\phi}$, and the parameters $\theta$, $\rho$ and $\phi$ can be learned minimizing suitable loss functions.
#
# For this purpose, given a time series $X = \{x_k | k = 1 \ldots N \}$, the following conditions hold:
#
#
# 1.   Reconstruction error
#      $$
#      \Vert \varphi_\rho (g_\theta(x_k)) - x_k  \Vert = 0
#      $$
# 2.   Prediction error in Koopman space
#      $$
#      \Vert \mathbf{K_{\phi}} g_{\theta} ( x_k ) - g_{\theta} (x_{k+1})  \Vert = 0
#      $$
# 3.   Prediction error in the phase space
#      $$
#      \Vert \varphi_{\rho} \left( \mathbf{K_{\phi}} g_{\theta} ( x_k )\right) - x_{k+1} \Vert = 0
#      $$
#
# The last three errors can be used as loss functions to train three different neural networks. These different neural networks compose our architecture that can be summarized as in the following sketch:

# %% [markdown]
# ![architecture](./architecture.png)

# %%
# Flatten the trajectories w.r.t. initial conditions
# and only keep data in the form of (dim_system, n_iter * n_initial_conditions)
matrix_x_data = array3d_xt[:, :, :-1].swapaxes(0, 1).reshape(2, -1).T
matrix_x_next_data = array3d_xt[:, :, 1:].swapaxes(0, 1).reshape(2, -1).T

(matrix_x_data_train,
 matrix_x_data_test,
 matrix_x_next_data_train,
 matrix_x_next_data_test) = train_test_split(matrix_x_data,
                                             matrix_x_next_data,
                                             test_size=0.2)

# Cast type to float32
matrix_x_data_train = matrix_x_data_train.astype(np.float32)
matrix_x_data_test = matrix_x_data_test.astype(np.float32)
matrix_x_next_data_train = matrix_x_next_data_train.astype(np.float32)
matrix_x_next_data_test = matrix_x_next_data_test.astype(np.float32)

print(matrix_x_data_train.shape,
      matrix_x_data_test.shape,
      matrix_x_next_data_train.shape,
      matrix_x_next_data_test.shape)
# Out:
# (239952, 2) (59988, 2) (239952, 2) (59988, 2)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
torch.set_default_dtype(torch.float32)
# torch.set_default_tensor_type('torch.DoubleTensor')

batch_size = 2000  # data per batch

tensor2d_x_data_train = torch.from_numpy(matrix_x_data_train).to(device)
tensor2d_x_next_data_train = torch.from_numpy(matrix_x_next_data_train).to(device)
tensor2d_x_data_test = torch.from_numpy(matrix_x_data_test).to(device)
tensor2d_x_next_data_test = torch.from_numpy(matrix_x_next_data_test).to(device)

torch_dataset_train = TensorDataset(tensor2d_x_data_train,
                                    tensor2d_x_next_data_train)

torch_dataset_test = TensorDataset(tensor2d_x_data_test,
                                   tensor2d_x_next_data_test)

train_dataloader = DataLoader(torch_dataset_train,
                              batch_size=batch_size,
                              shuffle=True)
test_dataloader = DataLoader(torch_dataset_test,
                             batch_size=batch_size,
                             shuffle=True)

# create the models
feature_dim = 2  # dimension of the Duffing oscillator
hidden_layer = 5  # number of hidden layers in g (ENCODER) and \varphi (DECODER)
output_dim = 30  # dimension in Koopman space

# %%
class Encoder(nn.Module):
    def __init__(self, list_layer_dim: list):
        super().__init__()
        self.list_layer_dim = list_layer_dim
        self.list_FC = nn.ModuleList()
        for i in range(len(self.list_layer_dim) - 1):
            input_dim = self.list_layer_dim[i]
            output_dim = self.list_layer_dim[i + 1]
            self.list_FC.append(nn.Linear(input_dim, output_dim))

    def forward(self, tensor2d_x):
        for i in range(len(self.list_layer_dim) - 2):
            tensor2d_x = F.elu(self.list_FC[i](tensor2d_x))
        return self.list_FC[-1](tensor2d_x)

# %%
class Decoder(nn.Module):
    def __init__(self, list_layer_dim: list):
        super().__init__()
        self.list_layer_dim = list_layer_dim
        self.list_FC = nn.ModuleList()
        for i in range(len(self.list_layer_dim) - 1, 0, -1):
            input_dim = self.list_layer_dim[i]
            output_dim = self.list_layer_dim[i - 1]
            self.list_FC.append(nn.Linear(input_dim, output_dim))

    def forward(self, tensor2d_x: torch.Tensor):
        for i in range(len(self.list_layer_dim) - 2):
            tensor2d_x = F.elu(self.list_FC[i](tensor2d_x))
        return self.list_FC[-1](tensor2d_x)

# %%
class Autoencoder(nn.Module):
    def __init__(self, feature_dim: int, hidden_layer: int, output_dim: int):
        super().__init__()
        list_layer_dim = \
            [output_dim if i == hidden_layer
             else feature_dim + i * (output_dim - feature_dim) // hidden_layer
             for i in range(hidden_layer + 1)]
        self.encoder = Encoder(list_layer_dim)
        self.decoder = Decoder(list_layer_dim)

    def forward(self, tensor2d_x: torch.Tensor):
        tensor2d_x = self.Encoder(tensor2d_x)
        return self.Decoder(tensor2d_x)

# %% [markdown]
# The Koopman operator $\mathbf{K}$ (which is linear, and thus a matrix) must have a [spectral radius](https://en.wikipedia.org/wiki/Spectral_radius) $\rho(\mathbf{K})\le 1$. Such condition will provide a stable -or at least a marginally stable- Koopman operator. To fulfill this requirement, we might leverage on the Perron-Frobenius theorem.
#
# The Perron-Frobenius th. states: if $\mathbf{K}$ is a $m \times m$ positive matrix i.e. $k_{ij} > 0$ for $1 \le i,j \le m$, then the following inequality holds:
#
# $$
# \min_i \sum_j k_{ij} \le \rho(\mathbf{K}) \le \max_i \sum_j k_{ij}
# $$

# %% [markdown]
# **Question 1.** : Complete the `KoopmanModule` class to enforce $\rho(\mathbf{K})\le 1$, using the Perron-Frobenius theorem. Check that the initialization fulfills this property.

# %%
class KoopmanOperator(nn.Module):
    def __init__(self, koopman_operator_dim: int):
        super().__init__()
        self.koopman_operator_dim = koopman_operator_dim
        # TODO: Complete the KoopmanOperator class
        self.weight_matrix = nn.Parameter(torch.randn(koopman_operator_dim, koopman_operator_dim))
        self._normalize_weights()

    def _normalize_weights(self):
        # We calculate the row sums of the weight matrix
        row_sums = self.weight_matrix.data.sum(dim=1)
        # We find the maximum row sum
        max_row_sum = torch.max(row_sums)

        if max_row_sum > 1:
            # Scale the weight matrix if the maximum row sum is greater than 1
            self.weight_matrix.data /= (max_row_sum + 0.05) # 0.05 to ensure it's under 1

    def _check_spectral_radius(self):
        eigenvalues = torch.linalg.eigvals(self.weight_matrix.data)
        spectral_radius = torch.max(torch.abs(eigenvalues))
        return spectral_radius

    def forward(self, tensor2d_x: torch.Tensor):
        # First dimension of tensor2d_x is the batch size
        if tensor2d_x.shape[1] != self.koopman_operator_dim:
            sys.exit(f'Wrong Input Features. Please use tensor'
                     f' with {self.koopman_operator_dim} Input Features')
        # TODO: Implement the forward pass
        return torch.matmul(tensor2d_x, self.weight_matrix.t())


dim_observable = 10
koopman_operator = KoopmanOperator(dim_observable)

# %%
# TODO: Check the spectrum initialisation
print(f"Spectral radius: {koopman_operator._check_spectral_radius().item()}")
# Out:
# Spectral radius: 0.2861444652080536

# %%
autoencoder = Autoencoder(feature_dim, hidden_layer, output_dim).to(device)
koopman_operator = KoopmanOperator(output_dim).to(device)
print(autoencoder)
# Out:
# Autoencoder(
#   (encoder): Encoder(
#     (list_FC): ModuleList(
#       (0): Linear(in_features=2, out_features=7, bias=True)
#       (1): Linear(in_features=7, out_features=13, bias=True)
#       (2): Linear(in_features=13, out_features=18, bias=True)
#       (3): Linear(in_features=18, out_features=24, bias=True)
#       (4): Linear(in_features=24, out_features=30, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (list_FC): ModuleList(
#       (0): Linear(in_features=30, out_features=24, bias=True)
#       (1): Linear(in_features=24, out_features=18, bias=True)
#       (2): Linear(in_features=18, out_features=13, bias=True)
#       (3): Linear(in_features=13, out_features=7, bias=True)
#       (4): Linear(in_features=7, out_features=2, bias=True)
#     )
#   )
# )

# %%
learning_rate_autoencoder = 0.0001
learning_rate_koopman = 0.00001

optimiser_autoencoder = torch.optim.Adam(autoencoder.parameters(),
                                         lr=learning_rate_autoencoder)

optimiser_koopman = torch.optim.Adam(koopman_operator.parameters(),
                                     lr=learning_rate_koopman)

# %% [markdown]
# **Question 2.** : Define a function to compute the loss to be minimized. It should at least include the 3 terms listed above:
# - Reconstruction error
# - Prediction error in the Koopman space
# - Prediction error in the phase space
#
# Because the different objectives outlined by these losses may compete, the training can be difficult. You may try different variations on these losses and comment your findings. In order to improve the training process, one can for instance:
# - Add a multiplicative factor in front of each loss component, to balance their importance; how the scales of different losses are related?
# - We can refine the loss acting upon the latent space, by using a variational autoencoder approach. This is similar to the Gaussian likelihood used in the first practical (TD1). We want the prediction in the latent space (i.e. the Koopman space) to be a normal distribution $\mathcal{N}(0, 1)$ . Add a corresponding loss for the latent space. Difference to 0 mean and 1 standard deviation must be thus included in the loss;
# - Freeze the gradients of one part of the network, for instance the encoder, for one specific objective, using the [`requires_grad`](https://pytorch.org/docs/stable/generated/torch.Tensor.requires_grad_.html) property. For instance:
# ```python
# criterion = nn.MSELoss()
# ...
# # Compute one part loss_l of the total loss
# # First deactivate gradient computation for irrelevant parts of the architecture
# for p in autoencoder.encoder.parameters():
#     p.requires_grad = False
# loss_l = criterion(pred, target)
# # Restore the gradient computation
# for p in autoencoder.encoder.parameters():
#     p.requires_grad = True
# ...
# total_loss = loss_1 + ... + loss_l + ...
# ```

# %%
import torch
import torch.nn as nn

def loss_koopman(tensor2d_x: torch.Tensor,
                 tensor2d_x_next: torch.Tensor,
                 tensor2d_decoded_x: torch.Tensor,
                 tensor2d_observable: torch.Tensor,
                 tensor2d_observable_next: torch.Tensor,
                 tensor2d_koopman_observable_next: torch.Tensor,
                 tensor2d_predict_x_next: torch.Tensor,
                 lambda_recon: float = 0.33,
                 lambda_koopman: float = 0.33,
                 lambda_prediction: float = 0.33,
                 lambda_kl: float = 0.33,
                 kl_term: bool = True
                 ):
    """
    Compute the total loss with optional independent gradient freezing
    on encoder/decoder/koopman during each specific loss computation.
    """
    criterion = nn.MSELoss()

    # Reconstruction loss
    recon_loss = criterion(tensor2d_decoded_x, tensor2d_x)

    # Koopman loss
    koopman_loss = criterion(tensor2d_koopman_observable_next, tensor2d_observable_next)

    # KL penalization (Hint 2)
    if kl_term:
        kl_loss = torch.abs(torch.mean(tensor2d_observable))+torch.abs(torch.std(tensor2d_observable)-1)

    # Freeze encoder layers for prediction loss
    for p in autoencoder.encoder.parameters():
        p.requires_grad = False

    prediction_loss = criterion(tensor2d_predict_x_next, tensor2d_x_next)

    for p in autoencoder.encoder.parameters():
        p.requires_grad = True

    if kl_term:
        total_loss = lambda_recon*recon_loss + lambda_koopman*koopman_loss+lambda_prediction*prediction_loss+lambda_kl*kl_loss
        return total_loss, recon_loss, koopman_loss, prediction_loss, kl_loss
    else:
        total_loss = lambda_recon*recon_loss + lambda_koopman*koopman_loss+lambda_prediction*prediction_loss
        return total_loss, recon_loss, koopman_loss, prediction_loss

# %% [markdown]
# 1.   Reconstruction error
# $$
# \Vert \varphi_\rho (g_\theta(x_k)) - x_k  \Vert = 0
# $$
# 2.   Prediction error in Koopman space
# $$
# \Vert \mathbf{K_{\phi}} g_{\theta} ( x_k ) - g_{\theta} (x_{k+1})  \Vert = 0
# $$
# 3.   Prediction error in the phase space
# $$
# \Vert \varphi_{\rho} \left( \mathbf{K_{\phi}} g_{\theta} ( x_k )\right) - x_{k+1} \Vert = 0
# $$

# %% [markdown]
# **Question 3.**: The following cell executes the training loop. You can modify it in order to display the different intermediate losses computed in the function `LOSS` above. How do they evolve in time? Justify your final choice.

# %%
import matplotlib.pyplot as plt

# Hyperparameters
n_batch = len(train_dataloader)
n_epoch = 100
verbose = True
eval_interval = 1  # Evaluate every epoch

# Loss component storage
losses_log = {
    'train': {'total': [], 'rec': [], 'koopman': [], 'pred': [], 'kl': []},
    'test':  {'total': [], 'rec': [], 'koopman': [], 'pred': [], 'kl': []}
}

for epoch in range(n_epoch):
    autoencoder.train()
    koopman_operator.train()

    total_train_loss, total_recon_loss, total_koopman_loss, total_prediction_loss, total_kl_loss = 0, 0, 0, 0, 0

    for tensor2d_batch_x, tensor2d_batch_x_next in train_dataloader:
        tensor2d_batch_x = tensor2d_batch_x.to(device)
        tensor2d_batch_x_next = tensor2d_batch_x_next.to(device)

        optimiser_autoencoder.zero_grad()
        optimiser_koopman.zero_grad()

        # Forward pass
        tensor2d_observable = autoencoder.encoder(tensor2d_batch_x)
        tensor2d_observable_next = autoencoder.encoder(tensor2d_batch_x_next)
        tensor2d_decoded_x = autoencoder.decoder(tensor2d_observable)
        tensor2d_koopman_observable_next = koopman_operator(tensor2d_observable)
        tensor2d_predict_x_next = autoencoder.decoder(tensor2d_koopman_observable_next)

        # Compute all loss components
        tensor_loss_val, r_error, koopman_error, pred_error, kl_error = loss_koopman(
            tensor2d_batch_x,
            tensor2d_batch_x_next,
            tensor2d_decoded_x,
            tensor2d_observable,
            tensor2d_observable_next,
            tensor2d_koopman_observable_next,
            tensor2d_predict_x_next
        )

        # Backpropagation
        tensor_loss_val.backward()
        optimiser_autoencoder.step()
        optimiser_koopman.step()

        # Accumulate
        total_train_loss += tensor_loss_val.item()
        total_recon_loss += r_error.item()
        total_koopman_loss += koopman_error.item()
        total_prediction_loss += pred_error.item()
        total_kl_loss += kl_error.item()

    # Average the losses per batch
    avg_total_loss = total_train_loss / n_batch
    avg_recon_loss = total_recon_loss / n_batch
    avg_koopman_loss = total_koopman_loss / n_batch
    avg_pred_loss = total_prediction_loss / n_batch
    avg_kl_loss = total_kl_loss / n_batch

    # After averaging training losses per epoch
    losses_log['train']['total'].append(avg_total_loss)
    losses_log['train']['rec'].append(avg_recon_loss)
    losses_log['train']['koopman'].append(avg_koopman_loss)
    losses_log['train']['pred'].append(avg_pred_loss)
    losses_log['train']['kl'].append(avg_kl_loss)

    # Verbose output
    if verbose:
        if avg_kl_loss > 0:
            print(f"EPOCH [{epoch+1}/{n_epoch}] | Total Loss: {avg_total_loss:.6f} | Recon Loss: {avg_recon_loss:.6f} | Koopman Loss: {avg_koopman_loss:.6f} | Prediction Loss: {avg_pred_loss:.6f} | KL Loss: {avg_kl_loss:.6f}")
        else:
            print(f"EPOCH [{epoch+1}/{n_epoch}] | Total Loss: {avg_total_loss:.6f} | Recon Loss: {avg_recon_loss:.6f} | Koopman Loss: {avg_koopman_loss:.6f} | Prediction Loss: {avg_pred_loss:.6f}")


    # Validation
    if epoch % eval_interval == 0 or epoch == n_epoch - 1:
        autoencoder.eval()
        koopman_operator.eval()

        total_test_loss, total_test_recon_loss, total_test_koopman_loss, total_test_pred_loss , total_test_kl_loss = 0, 0, 0, 0, 0
        test_batches = 0

        with torch.no_grad():
            for tensor2d_batch_x, tensor2d_batch_x_next in test_dataloader:
                tensor2d_batch_x = tensor2d_batch_x.to(device)
                tensor2d_batch_x_next = tensor2d_batch_x_next.to(device)

                # Forward pass
                tensor2d_observable = autoencoder.encoder(tensor2d_batch_x)
                tensor2d_observable_next = autoencoder.encoder(tensor2d_batch_x_next)
                tensor2d_decoded_x = autoencoder.decoder(tensor2d_observable)
                tensor2d_koopman_observable_next = koopman_operator(tensor2d_observable)
                tensor2d_predict_x_next = autoencoder.decoder(tensor2d_koopman_observable_next)

                # Compute losses (no backward here)
                tensor_loss_val, r_error, koopman_error, pred_error, kl_error = loss_koopman(
                    tensor2d_batch_x,
                    tensor2d_batch_x_next,
                    tensor2d_decoded_x,
                    tensor2d_observable,
                    tensor2d_observable_next,
                    tensor2d_koopman_observable_next,
                    tensor2d_predict_x_next
                )

                # Accumulate test losses
                total_test_loss += tensor_loss_val.item()
                total_test_recon_loss += r_error.item()
                total_test_koopman_loss += koopman_error.item()
                total_test_pred_loss += pred_error.item()
                total_test_kl_loss += kl_error.item()
                test_batches += 1

        # Average test losses per batch
        avg_test_loss = total_test_loss / test_batches
        avg_test_recon = total_test_recon_loss / test_batches
        avg_test_koopman = total_test_koopman_loss / test_batches
        avg_test_pred = total_test_pred_loss / test_batches
        avg_test_kl = total_test_kl_loss / test_batches

        losses_log['test']['total'].append(avg_test_loss)
        losses_log['test']['rec'].append(avg_test_recon)
        losses_log['test']['koopman'].append(avg_test_koopman)
        losses_log['test']['pred'].append(avg_test_pred)
        losses_log['test']['kl'].append(avg_test_kl)

        # Optional printing based on verbose
        if verbose:
            if avg_test_kl > 0:
                print(f"TEST  [{epoch+1}/{n_epoch}] | Total Loss: {avg_test_loss:.6f} | Recon Loss: {avg_test_recon:.6f} | Koopman Loss: {avg_test_koopman:.6f} | Prediction Loss: {avg_test_pred:.6f} | KL Loss: {avg_test_kl:.6f}")
            else:
                print(f"TEST  [{epoch+1}/{n_epoch}] | Total Loss: {avg_test_loss:.6f} | Recon Loss: {avg_test_recon:.6f} | Koopman Loss: {avg_test_koopman:.6f} | Prediction Loss: {avg_test_pred:.6f}")
            print(f"{'-'*110}")

import matplotlib.pyplot as plt

loss_names = ['total', 'rec', 'koopman', 'pred', 'kl']
titles = ['Total Loss', 'Reconstruction Loss', 'Koopman Loss', 'Prediction Loss', 'KL Loss']

if not any(losses_log['train']['kl']) and not any(losses_log['test']['kl']):
    loss_names = loss_names[:-1]
    fig, axs = plt.subplots(1, 4, figsize=(15,5), sharex=True, sharey=True)
else:
    fig, axs = plt.subplots(1, 5, figsize=(15, 5), sharex=True, sharey=True)
axs = axs.flatten()

for i, loss_key in enumerate(loss_names):
    axs[i].plot(losses_log['train'][loss_key], label='Train')
    axs[i].plot(losses_log['test'][loss_key], label='Test', linestyle='--')
    axs[i].set_title(titles[i])
    axs[i].set_xlabel('Epoch')
    axs[i].legend()
    axs[i].grid(True)

plt.tight_layout()
plt.show()

# Save logs json
import json
with open('losses_log.json', 'w') as f:
    json.dump(losses_log, f)
# Out:
# EPOCH [1/100] | Total Loss: 1.450977 | Recon Loss: 1.757607 | Koopman Loss: 0.039977 | Prediction Loss: 1.764405 | KL Loss: 0.834912
# TEST  [1/100] | Total Loss: 1.427107 | Recon Loss: 1.728522 | Koopman Loss: 0.049806 | Prediction Loss: 1.745079 | KL Loss: 0.801158
# --------------------------------------------------------------------------------------------------------------
# EPOCH [2/100] | Total Loss: 1.386041 | Recon Loss: 1.667570 | Koopman Loss: 0.064193 | Prediction Loss: 1.710946 | KL Loss: 0.757415
# TEST  [2/100] | Total Loss: 1.315677 | Recon Loss: 1.553780 | Koopman Loss: 0.082223 | Prediction Loss: 1.647766 | KL Loss: 0.703132
# --------------------------------------------------------------------------------------------------------------
# EPOCH [3/100] | Total Loss: 1.101409 | Recon Loss: 1.217798 | Koopman Loss: 0.114156 | Prediction Loss: 1.379404 | KL Loss: 0.626244
# TEST  [3/100] | Total Loss: 0.814946 | Recon Loss: 0.798557 | Koopman Loss: 0.157166 | Prediction Loss: 0.973772 | KL Loss: 0.540037
# --------------------------------------------------------------------------------------------------------------
# EPOCH [4/100] | Total Loss: 0.598545 | Recon Loss: 0.515116 | Koopman Loss: 0.188186 | Prediction Loss: 0.635434 | KL Loss: 0.475036
# TEST  [4/100] | Total Loss: 0.419179 | Recon Loss: 0.290767 | Koopman Loss: 0.205879 | Prediction Loss: 0.354688 | KL Loss: 0.418907
# --------------------------------------------------------------------------------------------------------------
# EPOCH [5/100] | Total Loss: 0.330792 | Recon Loss: 0.193007 | Koopman Loss: 0.207611 | Prediction Loss: 0.223545 | KL Loss: 0.378237
# TEST  [5/100] | Total Loss: 0.274274 | Recon Loss: 0.135447 | Koopman Loss: 0.206811 | Prediction Loss: 0.149142 | KL Loss: 0.339734
# --------------------------------------------------------------------------------------------------------------
# EPOCH [6/100] | Total Loss: 0.246848 | Recon Loss: 0.119662 | Koopman Loss: 0.206344 | Prediction Loss: 0.127467 | KL Loss: 0.294551
# TEST  [6/100] | Total Loss: 0.221732 | Recon Loss: 0.110510 | Koopman Loss: 0.208285 | Prediction Loss: 0.114105 | KL Loss: 0.239015
# --------------------------------------------------------------------------------------------------------------
# EPOCH [7/100] | Total Loss: 0.196538 | Recon Loss: 0.108928 | Koopman Loss: 0.216444 | Prediction Loss: 0.110971 | KL Loss: 0.159227
# TEST  [7/100] | Total Loss: 0.166650 | Recon Loss: 0.107230 | Koopman Loss: 0.229574 | Prediction Loss: 0.108982 | KL Loss: 0.059213
# --------------------------------------------------------------------------------------------------------------
# EPOCH [8/100] | Total Loss: 0.145811 | Recon Loss: 0.101746 | Koopman Loss: 0.216752 | Prediction Loss: 0.107716 | KL Loss: 0.015638
# TEST  [8/100] | Total Loss: 0.131542 | Recon Loss: 0.095091 | Koopman Loss: 0.192325 | Prediction Loss: 0.103509 | KL Loss: 0.007686
# --------------------------------------------------------------------------------------------------------------
# EPOCH [9/100] | Total Loss: 0.122591 | Recon Loss: 0.090689 | Koopman Loss: 0.171232 | Prediction Loss: 0.099951 | KL Loss: 0.009616
# TEST  [9/100] | Total Loss: 0.113342 | Recon Loss: 0.085681 | Koopman Loss: 0.154929 | Prediction Loss: 0.095735 | KL Loss: 0.007114
# --------------------------------------------------------------------------------------------------------------
# EPOCH [10/100] | Total Loss: 0.107479 | Recon Loss: 0.082262 | Koopman Loss: 0.140803 | Prediction Loss: 0.092767 | KL Loss: 0.009861
# TEST  [10/100] | Total Loss: 0.100183 | Recon Loss: 0.078004 | Koopman Loss: 0.128159 | Prediction Loss: 0.088792 | KL Loss: 0.008631
# --------------------------------------------------------------------------------------------------------------
# EPOCH [11/100] | Total Loss: 0.095496 | Recon Loss: 0.075252 | Koopman Loss: 0.118623 | Prediction Loss: 0.086173 | KL Loss: 0.009334
# TEST  [11/100] | Total Loss: 0.090342 | Recon Loss: 0.071795 | Koopman Loss: 0.110098 | Prediction Loss: 0.082608 | KL Loss: 0.009264
# --------------------------------------------------------------------------------------------------------------
# EPOCH [12/100] | Total Loss: 0.085300 | Recon Loss: 0.068947 | Koopman Loss: 0.101202 | Prediction Loss: 0.080170 | KL Loss: 0.008166
# TEST  [12/100] | Total Loss: 0.081948 | Recon Loss: 0.065819 | Koopman Loss: 0.094733 | Prediction Loss: 0.076809 | KL Loss: 0.010965
# --------------------------------------------------------------------------------------------------------------
# EPOCH [13/100] | Total Loss: 0.077004 | Recon Loss: 0.063122 | Koopman Loss: 0.086951 | Prediction Loss: 0.074494 | KL Loss: 0.008777
# TEST  [13/100] | Total Loss: 0.072753 | Recon Loss: 0.060014 | Koopman Loss: 0.080293 | Prediction Loss: 0.071357 | KL Loss: 0.008799
# --------------------------------------------------------------------------------------------------------------
# EPOCH [14/100] | Total Loss: 0.069599 | Recon Loss: 0.057713 | Koopman Loss: 0.075143 | Prediction Loss: 0.069110 | KL Loss: 0.008939
# TEST  [14/100] | Total Loss: 0.066381 | Recon Loss: 0.054756 | Koopman Loss: 0.069497 | Prediction Loss: 0.066078 | KL Loss: 0.010822
# --------------------------------------------------------------------------------------------------------------
# EPOCH [15/100] | Total Loss: 0.063013 | Recon Loss: 0.052571 | Koopman Loss: 0.065020 | Prediction Loss: 0.063866 | KL Loss: 0.009491
# TEST  [15/100] | Total Loss: 0.059509 | Recon Loss: 0.049703 | Koopman Loss: 0.060896 | Prediction Loss: 0.061228 | KL Loss: 0.008503
# --------------------------------------------------------------------------------------------------------------
# EPOCH [16/100] | Total Loss: 0.056634 | Recon Loss: 0.047665 | Koopman Loss: 0.056573 | Prediction Loss: 0.058933 | KL Loss: 0.008448
# TEST  [16/100] | Total Loss: 0.053762 | Recon Loss: 0.045018 | Koopman Loss: 0.052929 | Prediction Loss: 0.056206 | KL Loss: 0.008762
# --------------------------------------------------------------------------------------------------------------
# EPOCH [17/100] | Total Loss: 0.051403 | Recon Loss: 0.042950 | Koopman Loss: 0.049311 | Prediction Loss: 0.054093 | KL Loss: 0.009414
# TEST  [17/100] | Total Loss: 0.048161 | Recon Loss: 0.040384 | Koopman Loss: 0.045956 | Prediction Loss: 0.051521 | KL Loss: 0.008081
# --------------------------------------------------------------------------------------------------------------
# EPOCH [18/100] | Total Loss: 0.046176 | Recon Loss: 0.038373 | Koopman Loss: 0.043132 | Prediction Loss: 0.049413 | KL Loss: 0.009010
# TEST  [18/100] | Total Loss: 0.043474 | Recon Loss: 0.035877 | Koopman Loss: 0.040608 | Prediction Loss: 0.047069 | KL Loss: 0.008187
# --------------------------------------------------------------------------------------------------------------
# EPOCH [19/100] | Total Loss: 0.041656 | Recon Loss: 0.033976 | Koopman Loss: 0.038069 | Prediction Loss: 0.044906 | KL Loss: 0.009280
# TEST  [19/100] | Total Loss: 0.039601 | Recon Loss: 0.031677 | Koopman Loss: 0.035902 | Prediction Loss: 0.042556 | KL Loss: 0.009869
# --------------------------------------------------------------------------------------------------------------
# EPOCH [20/100] | Total Loss: 0.037141 | Recon Loss: 0.029809 | Koopman Loss: 0.033576 | Prediction Loss: 0.040560 | KL Loss: 0.008604
# TEST  [20/100] | Total Loss: 0.035261 | Recon Loss: 0.027758 | Koopman Loss: 0.031784 | Prediction Loss: 0.038315 | KL Loss: 0.008995
# --------------------------------------------------------------------------------------------------------------
# EPOCH [21/100] | Total Loss: 0.033700 | Recon Loss: 0.025889 | Koopman Loss: 0.029991 | Prediction Loss: 0.036418 | KL Loss: 0.009824
# TEST  [21/100] | Total Loss: 0.031420 | Recon Loss: 0.023963 | Koopman Loss: 0.028606 | Prediction Loss: 0.034307 | KL Loss: 0.008336
# --------------------------------------------------------------------------------------------------------------
# EPOCH [22/100] | Total Loss: 0.029733 | Recon Loss: 0.022224 | Koopman Loss: 0.027018 | Prediction Loss: 0.032498 | KL Loss: 0.008359
# TEST  [22/100] | Total Loss: 0.027942 | Recon Loss: 0.020464 | Koopman Loss: 0.025775 | Prediction Loss: 0.030529 | KL Loss: 0.007906
# --------------------------------------------------------------------------------------------------------------
# EPOCH [23/100] | Total Loss: 0.026721 | Recon Loss: 0.018903 | Koopman Loss: 0.024414 | Prediction Loss: 0.028803 | KL Loss: 0.008853
# TEST  [23/100] | Total Loss: 0.025374 | Recon Loss: 0.017241 | Koopman Loss: 0.023508 | Prediction Loss: 0.027072 | KL Loss: 0.009068
# --------------------------------------------------------------------------------------------------------------
# EPOCH [24/100] | Total Loss: 0.024039 | Recon Loss: 0.015887 | Koopman Loss: 0.022331 | Prediction Loss: 0.025389 | KL Loss: 0.009239
# TEST  [24/100] | Total Loss: 0.022407 | Recon Loss: 0.014409 | Koopman Loss: 0.021549 | Prediction Loss: 0.023694 | KL Loss: 0.008247
# --------------------------------------------------------------------------------------------------------------
# EPOCH [25/100] | Total Loss: 0.021367 | Recon Loss: 0.013189 | Koopman Loss: 0.020683 | Prediction Loss: 0.022224 | KL Loss: 0.008652
# TEST  [25/100] | Total Loss: 0.020742 | Recon Loss: 0.011992 | Koopman Loss: 0.019815 | Prediction Loss: 0.020647 | KL Loss: 0.010400
# --------------------------------------------------------------------------------------------------------------
# EPOCH [26/100] | Total Loss: 0.019699 | Recon Loss: 0.010874 | Koopman Loss: 0.019216 | Prediction Loss: 0.019379 | KL Loss: 0.010226
# TEST  [26/100] | Total Loss: 0.017983 | Recon Loss: 0.009809 | Koopman Loss: 0.018617 | Prediction Loss: 0.018074 | KL Loss: 0.007995
# --------------------------------------------------------------------------------------------------------------
# EPOCH [27/100] | Total Loss: 0.017674 | Recon Loss: 0.008944 | Koopman Loss: 0.018025 | Prediction Loss: 0.016893 | KL Loss: 0.009695
# TEST  [27/100] | Total Loss: 0.016161 | Recon Loss: 0.008102 | Koopman Loss: 0.017540 | Prediction Loss: 0.015765 | KL Loss: 0.007567
# --------------------------------------------------------------------------------------------------------------
# EPOCH [28/100] | Total Loss: 0.015962 | Recon Loss: 0.007464 | Koopman Loss: 0.016975 | Prediction Loss: 0.014825 | KL Loss: 0.009107
# TEST  [28/100] | Total Loss: 0.014561 | Recon Loss: 0.006821 | Koopman Loss: 0.016651 | Prediction Loss: 0.013888 | KL Loss: 0.006763
# --------------------------------------------------------------------------------------------------------------
# EPOCH [29/100] | Total Loss: 0.014760 | Recon Loss: 0.006371 | Koopman Loss: 0.016104 | Prediction Loss: 0.013149 | KL Loss: 0.009104
# TEST  [29/100] | Total Loss: 0.013204 | Recon Loss: 0.005865 | Koopman Loss: 0.015737 | Prediction Loss: 0.012419 | KL Loss: 0.005991
# --------------------------------------------------------------------------------------------------------------
# EPOCH [30/100] | Total Loss: 0.013749 | Recon Loss: 0.005573 | Koopman Loss: 0.015287 | Prediction Loss: 0.011822 | KL Loss: 0.008981
# TEST  [30/100] | Total Loss: 0.013304 | Recon Loss: 0.005223 | Koopman Loss: 0.015063 | Prediction Loss: 0.011303 | KL Loss: 0.008725
# --------------------------------------------------------------------------------------------------------------
# EPOCH [31/100] | Total Loss: 0.013195 | Recon Loss: 0.005023 | Koopman Loss: 0.014525 | Prediction Loss: 0.010784 | KL Loss: 0.009654
# TEST  [31/100] | Total Loss: 0.012376 | Recon Loss: 0.004739 | Koopman Loss: 0.014246 | Prediction Loss: 0.010337 | KL Loss: 0.008182
# --------------------------------------------------------------------------------------------------------------
# EPOCH [32/100] | Total Loss: 0.012612 | Recon Loss: 0.004609 | Koopman Loss: 0.013893 | Prediction Loss: 0.009961 | KL Loss: 0.009755
# TEST  [32/100] | Total Loss: 0.012163 | Recon Loss: 0.004378 | Koopman Loss: 0.013692 | Prediction Loss: 0.009642 | KL Loss: 0.009147
# --------------------------------------------------------------------------------------------------------------
# EPOCH [33/100] | Total Loss: 0.011956 | Recon Loss: 0.004293 | Koopman Loss: 0.013274 | Prediction Loss: 0.009247 | KL Loss: 0.009416
# TEST  [33/100] | Total Loss: 0.011509 | Recon Loss: 0.004149 | Koopman Loss: 0.013058 | Prediction Loss: 0.008918 | KL Loss: 0.008752
# --------------------------------------------------------------------------------------------------------------
# EPOCH [34/100] | Total Loss: 0.011657 | Recon Loss: 0.004044 | Koopman Loss: 0.012695 | Prediction Loss: 0.008668 | KL Loss: 0.009917
# TEST  [34/100] | Total Loss: 0.012401 | Recon Loss: 0.003906 | Koopman Loss: 0.012585 | Prediction Loss: 0.008428 | KL Loss: 0.012661
# --------------------------------------------------------------------------------------------------------------
# EPOCH [35/100] | Total Loss: 0.011209 | Recon Loss: 0.003833 | Koopman Loss: 0.012177 | Prediction Loss: 0.008138 | KL Loss: 0.009817
# TEST  [35/100] | Total Loss: 0.011110 | Recon Loss: 0.003749 | Koopman Loss: 0.012024 | Prediction Loss: 0.007873 | KL Loss: 0.010022
# --------------------------------------------------------------------------------------------------------------
# EPOCH [36/100] | Total Loss: 0.010677 | Recon Loss: 0.003652 | Koopman Loss: 0.011679 | Prediction Loss: 0.007682 | KL Loss: 0.009342
# TEST  [36/100] | Total Loss: 0.010458 | Recon Loss: 0.003516 | Koopman Loss: 0.011459 | Prediction Loss: 0.007484 | KL Loss: 0.009230
# --------------------------------------------------------------------------------------------------------------
# EPOCH [37/100] | Total Loss: 0.010298 | Recon Loss: 0.003498 | Koopman Loss: 0.011193 | Prediction Loss: 0.007262 | KL Loss: 0.009254
# TEST  [37/100] | Total Loss: 0.010383 | Recon Loss: 0.003400 | Koopman Loss: 0.010997 | Prediction Loss: 0.007071 | KL Loss: 0.009994
# --------------------------------------------------------------------------------------------------------------
# EPOCH [38/100] | Total Loss: 0.009945 | Recon Loss: 0.003377 | Koopman Loss: 0.010750 | Prediction Loss: 0.006901 | KL Loss: 0.009110
# TEST  [38/100] | Total Loss: 0.009481 | Recon Loss: 0.003286 | Koopman Loss: 0.010622 | Prediction Loss: 0.006714 | KL Loss: 0.008108
# --------------------------------------------------------------------------------------------------------------
# EPOCH [39/100] | Total Loss: 0.009374 | Recon Loss: 0.003263 | Koopman Loss: 0.010326 | Prediction Loss: 0.006555 | KL Loss: 0.008262
# TEST  [39/100] | Total Loss: 0.008904 | Recon Loss: 0.003191 | Koopman Loss: 0.010174 | Prediction Loss: 0.006397 | KL Loss: 0.007219
# --------------------------------------------------------------------------------------------------------------
# EPOCH [40/100] | Total Loss: 0.009146 | Recon Loss: 0.003157 | Koopman Loss: 0.009920 | Prediction Loss: 0.006242 | KL Loss: 0.008396
# TEST  [40/100] | Total Loss: 0.009066 | Recon Loss: 0.003096 | Koopman Loss: 0.009808 | Prediction Loss: 0.006073 | KL Loss: 0.008495
# --------------------------------------------------------------------------------------------------------------
# EPOCH [41/100] | Total Loss: 0.008802 | Recon Loss: 0.003075 | Koopman Loss: 0.009516 | Prediction Loss: 0.005955 | KL Loss: 0.008126
# TEST  [41/100] | Total Loss: 0.009047 | Recon Loss: 0.003025 | Koopman Loss: 0.009387 | Prediction Loss: 0.005804 | KL Loss: 0.009199
# --------------------------------------------------------------------------------------------------------------
# EPOCH [42/100] | Total Loss: 0.008918 | Recon Loss: 0.002984 | Koopman Loss: 0.009156 | Prediction Loss: 0.005688 | KL Loss: 0.009197
# TEST  [42/100] | Total Loss: 0.008801 | Recon Loss: 0.002928 | Koopman Loss: 0.009087 | Prediction Loss: 0.005541 | KL Loss: 0.009112
# --------------------------------------------------------------------------------------------------------------
# EPOCH [43/100] | Total Loss: 0.008561 | Recon Loss: 0.002903 | Koopman Loss: 0.008809 | Prediction Loss: 0.005441 | KL Loss: 0.008788
# TEST  [43/100] | Total Loss: 0.008535 | Recon Loss: 0.002882 | Koopman Loss: 0.008695 | Prediction Loss: 0.005338 | KL Loss: 0.008949
# --------------------------------------------------------------------------------------------------------------
# EPOCH [44/100] | Total Loss: 0.008584 | Recon Loss: 0.002841 | Koopman Loss: 0.008522 | Prediction Loss: 0.005210 | KL Loss: 0.009440
# TEST  [44/100] | Total Loss: 0.008295 | Recon Loss: 0.002807 | Koopman Loss: 0.008450 | Prediction Loss: 0.005102 | KL Loss: 0.008778
# --------------------------------------------------------------------------------------------------------------
# EPOCH [45/100] | Total Loss: 0.008393 | Recon Loss: 0.002763 | Koopman Loss: 0.008231 | Prediction Loss: 0.004988 | KL Loss: 0.009454
# TEST  [45/100] | Total Loss: 0.008261 | Recon Loss: 0.002731 | Koopman Loss: 0.008095 | Prediction Loss: 0.004885 | KL Loss: 0.009324
# --------------------------------------------------------------------------------------------------------------
# EPOCH [46/100] | Total Loss: 0.007960 | Recon Loss: 0.002700 | Koopman Loss: 0.007939 | Prediction Loss: 0.004788 | KL Loss: 0.008694
# TEST  [46/100] | Total Loss: 0.007519 | Recon Loss: 0.002656 | Koopman Loss: 0.007846 | Prediction Loss: 0.004685 | KL Loss: 0.007598
# --------------------------------------------------------------------------------------------------------------
# EPOCH [47/100] | Total Loss: 0.008014 | Recon Loss: 0.002648 | Koopman Loss: 0.007644 | Prediction Loss: 0.004588 | KL Loss: 0.009405
# TEST  [47/100] | Total Loss: 0.007541 | Recon Loss: 0.002631 | Koopman Loss: 0.007577 | Prediction Loss: 0.004488 | KL Loss: 0.008155
# --------------------------------------------------------------------------------------------------------------
# EPOCH [48/100] | Total Loss: 0.007672 | Recon Loss: 0.002598 | Koopman Loss: 0.007387 | Prediction Loss: 0.004412 | KL Loss: 0.008852
# TEST  [48/100] | Total Loss: 0.007438 | Recon Loss: 0.002566 | Koopman Loss: 0.007303 | Prediction Loss: 0.004379 | KL Loss: 0.008292
# --------------------------------------------------------------------------------------------------------------
# EPOCH [49/100] | Total Loss: 0.007577 | Recon Loss: 0.002553 | Koopman Loss: 0.007137 | Prediction Loss: 0.004245 | KL Loss: 0.009025
# TEST  [49/100] | Total Loss: 0.007267 | Recon Loss: 0.002531 | Koopman Loss: 0.007069 | Prediction Loss: 0.004163 | KL Loss: 0.008257
# --------------------------------------------------------------------------------------------------------------
# EPOCH [50/100] | Total Loss: 0.007332 | Recon Loss: 0.002498 | Koopman Loss: 0.006891 | Prediction Loss: 0.004077 | KL Loss: 0.008753
# TEST  [50/100] | Total Loss: 0.007358 | Recon Loss: 0.002466 | Koopman Loss: 0.006793 | Prediction Loss: 0.004034 | KL Loss: 0.009003
# --------------------------------------------------------------------------------------------------------------
# EPOCH [51/100] | Total Loss: 0.007021 | Recon Loss: 0.002457 | Koopman Loss: 0.006654 | Prediction Loss: 0.003922 | KL Loss: 0.008242
# TEST  [51/100] | Total Loss: 0.007426 | Recon Loss: 0.002434 | Koopman Loss: 0.006608 | Prediction Loss: 0.003852 | KL Loss: 0.009607
# --------------------------------------------------------------------------------------------------------------
# EPOCH [52/100] | Total Loss: 0.007121 | Recon Loss: 0.002417 | Koopman Loss: 0.006433 | Prediction Loss: 0.003778 | KL Loss: 0.008951
# TEST  [52/100] | Total Loss: 0.007091 | Recon Loss: 0.002392 | Koopman Loss: 0.006392 | Prediction Loss: 0.003702 | KL Loss: 0.009002
# --------------------------------------------------------------------------------------------------------------
# EPOCH [53/100] | Total Loss: 0.006974 | Recon Loss: 0.002379 | Koopman Loss: 0.006201 | Prediction Loss: 0.003640 | KL Loss: 0.008914
# TEST  [53/100] | Total Loss: 0.007065 | Recon Loss: 0.002358 | Koopman Loss: 0.006117 | Prediction Loss: 0.003574 | KL Loss: 0.009362
# --------------------------------------------------------------------------------------------------------------
# EPOCH [54/100] | Total Loss: 0.006888 | Recon Loss: 0.002339 | Koopman Loss: 0.006002 | Prediction Loss: 0.003512 | KL Loss: 0.009019
# TEST  [54/100] | Total Loss: 0.007649 | Recon Loss: 0.002295 | Koopman Loss: 0.005858 | Prediction Loss: 0.003467 | KL Loss: 0.011560
# --------------------------------------------------------------------------------------------------------------
# EPOCH [55/100] | Total Loss: 0.006569 | Recon Loss: 0.002304 | Koopman Loss: 0.005797 | Prediction Loss: 0.003397 | KL Loss: 0.008409
# TEST  [55/100] | Total Loss: 0.007217 | Recon Loss: 0.002261 | Koopman Loss: 0.005704 | Prediction Loss: 0.003358 | KL Loss: 0.010549
# --------------------------------------------------------------------------------------------------------------
# EPOCH [56/100] | Total Loss: 0.006951 | Recon Loss: 0.002273 | Koopman Loss: 0.005613 | Prediction Loss: 0.003289 | KL Loss: 0.009888
# TEST  [56/100] | Total Loss: 0.006279 | Recon Loss: 0.002251 | Koopman Loss: 0.005562 | Prediction Loss: 0.003257 | KL Loss: 0.007957
# --------------------------------------------------------------------------------------------------------------
# EPOCH [57/100] | Total Loss: 0.006881 | Recon Loss: 0.002233 | Koopman Loss: 0.005454 | Prediction Loss: 0.003193 | KL Loss: 0.009973
# TEST  [57/100] | Total Loss: 0.006750 | Recon Loss: 0.002204 | Koopman Loss: 0.005358 | Prediction Loss: 0.003144 | KL Loss: 0.009749
# --------------------------------------------------------------------------------------------------------------
# EPOCH [58/100] | Total Loss: 0.006547 | Recon Loss: 0.002198 | Koopman Loss: 0.005290 | Prediction Loss: 0.003087 | KL Loss: 0.009265
# TEST  [58/100] | Total Loss: 0.006512 | Recon Loss: 0.002174 | Koopman Loss: 0.005220 | Prediction Loss: 0.003041 | KL Loss: 0.009299
# --------------------------------------------------------------------------------------------------------------
# EPOCH [59/100] | Total Loss: 0.006849 | Recon Loss: 0.002172 | Koopman Loss: 0.005132 | Prediction Loss: 0.003004 | KL Loss: 0.010446
# TEST  [59/100] | Total Loss: 0.006351 | Recon Loss: 0.002142 | Koopman Loss: 0.005068 | Prediction Loss: 0.002990 | KL Loss: 0.009047
# --------------------------------------------------------------------------------------------------------------
# EPOCH [60/100] | Total Loss: 0.006154 | Recon Loss: 0.002128 | Koopman Loss: 0.004983 | Prediction Loss: 0.002921 | KL Loss: 0.008617
# TEST  [60/100] | Total Loss: 0.006766 | Recon Loss: 0.002105 | Koopman Loss: 0.004898 | Prediction Loss: 0.002886 | KL Loss: 0.010615
# --------------------------------------------------------------------------------------------------------------
# EPOCH [61/100] | Total Loss: 0.006541 | Recon Loss: 0.002103 | Koopman Loss: 0.004831 | Prediction Loss: 0.002846 | KL Loss: 0.010042
# TEST  [61/100] | Total Loss: 0.006010 | Recon Loss: 0.002078 | Koopman Loss: 0.004781 | Prediction Loss: 0.002811 | KL Loss: 0.008542
# --------------------------------------------------------------------------------------------------------------
# EPOCH [62/100] | Total Loss: 0.006056 | Recon Loss: 0.002070 | Koopman Loss: 0.004685 | Prediction Loss: 0.002772 | KL Loss: 0.008825
# TEST  [62/100] | Total Loss: 0.006378 | Recon Loss: 0.002065 | Koopman Loss: 0.004677 | Prediction Loss: 0.002756 | KL Loss: 0.009830
# --------------------------------------------------------------------------------------------------------------
# EPOCH [63/100] | Total Loss: 0.006050 | Recon Loss: 0.002035 | Koopman Loss: 0.004563 | Prediction Loss: 0.002712 | KL Loss: 0.009025
# TEST  [63/100] | Total Loss: 0.006196 | Recon Loss: 0.002002 | Koopman Loss: 0.004531 | Prediction Loss: 0.002690 | KL Loss: 0.009554
# --------------------------------------------------------------------------------------------------------------
# EPOCH [64/100] | Total Loss: 0.005808 | Recon Loss: 0.002005 | Koopman Loss: 0.004440 | Prediction Loss: 0.002653 | KL Loss: 0.008504
# TEST  [64/100] | Total Loss: 0.006041 | Recon Loss: 0.001981 | Koopman Loss: 0.004438 | Prediction Loss: 0.002637 | KL Loss: 0.009249
# --------------------------------------------------------------------------------------------------------------
# EPOCH [65/100] | Total Loss: 0.006161 | Recon Loss: 0.001971 | Koopman Loss: 0.004322 | Prediction Loss: 0.002589 | KL Loss: 0.009787
# TEST  [65/100] | Total Loss: 0.005601 | Recon Loss: 0.001944 | Koopman Loss: 0.004308 | Prediction Loss: 0.002571 | KL Loss: 0.008150
# --------------------------------------------------------------------------------------------------------------
# EPOCH [66/100] | Total Loss: 0.006071 | Recon Loss: 0.001939 | Koopman Loss: 0.004220 | Prediction Loss: 0.002539 | KL Loss: 0.009699
# TEST  [66/100] | Total Loss: 0.005919 | Recon Loss: 0.001931 | Koopman Loss: 0.004239 | Prediction Loss: 0.002511 | KL Loss: 0.009256
# --------------------------------------------------------------------------------------------------------------
# EPOCH [67/100] | Total Loss: 0.006025 | Recon Loss: 0.001905 | Koopman Loss: 0.004122 | Prediction Loss: 0.002490 | KL Loss: 0.009739
# TEST  [67/100] | Total Loss: 0.005670 | Recon Loss: 0.001881 | Koopman Loss: 0.004098 | Prediction Loss: 0.002461 | KL Loss: 0.008740
# --------------------------------------------------------------------------------------------------------------
# EPOCH [68/100] | Total Loss: 0.005588 | Recon Loss: 0.001878 | Koopman Loss: 0.004036 | Prediction Loss: 0.002442 | KL Loss: 0.008578
# TEST  [68/100] | Total Loss: 0.005844 | Recon Loss: 0.001850 | Koopman Loss: 0.004020 | Prediction Loss: 0.002414 | KL Loss: 0.009424
# --------------------------------------------------------------------------------------------------------------
# EPOCH [69/100] | Total Loss: 0.005845 | Recon Loss: 0.001846 | Koopman Loss: 0.003945 | Prediction Loss: 0.002398 | KL Loss: 0.009523
# TEST  [69/100] | Total Loss: 0.005365 | Recon Loss: 0.001821 | Koopman Loss: 0.003887 | Prediction Loss: 0.002388 | KL Loss: 0.008163
# --------------------------------------------------------------------------------------------------------------
# EPOCH [70/100] | Total Loss: 0.005841 | Recon Loss: 0.001821 | Koopman Loss: 0.003864 | Prediction Loss: 0.002354 | KL Loss: 0.009660
# TEST  [70/100] | Total Loss: 0.006206 | Recon Loss: 0.001780 | Koopman Loss: 0.003795 | Prediction Loss: 0.002361 | KL Loss: 0.010869
# --------------------------------------------------------------------------------------------------------------
# EPOCH [71/100] | Total Loss: 0.005709 | Recon Loss: 0.001792 | Koopman Loss: 0.003787 | Prediction Loss: 0.002312 | KL Loss: 0.009408
# TEST  [71/100] | Total Loss: 0.005927 | Recon Loss: 0.001758 | Koopman Loss: 0.003715 | Prediction Loss: 0.002298 | KL Loss: 0.010190
# --------------------------------------------------------------------------------------------------------------
# EPOCH [72/100] | Total Loss: 0.005612 | Recon Loss: 0.001762 | Koopman Loss: 0.003712 | Prediction Loss: 0.002271 | KL Loss: 0.009261
# TEST  [72/100] | Total Loss: 0.005538 | Recon Loss: 0.001755 | Koopman Loss: 0.003714 | Prediction Loss: 0.002243 | KL Loss: 0.009071
# --------------------------------------------------------------------------------------------------------------
# EPOCH [73/100] | Total Loss: 0.005577 | Recon Loss: 0.001742 | Koopman Loss: 0.003631 | Prediction Loss: 0.002229 | KL Loss: 0.009296
# TEST  [73/100] | Total Loss: 0.005987 | Recon Loss: 0.001717 | Koopman Loss: 0.003581 | Prediction Loss: 0.002207 | KL Loss: 0.010638
# --------------------------------------------------------------------------------------------------------------
# EPOCH [74/100] | Total Loss: 0.005824 | Recon Loss: 0.001717 | Koopman Loss: 0.003569 | Prediction Loss: 0.002185 | KL Loss: 0.010176
# TEST  [74/100] | Total Loss: 0.005460 | Recon Loss: 0.001694 | Koopman Loss: 0.003540 | Prediction Loss: 0.002177 | KL Loss: 0.009135
# --------------------------------------------------------------------------------------------------------------
# EPOCH [75/100] | Total Loss: 0.005231 | Recon Loss: 0.001693 | Koopman Loss: 0.003497 | Prediction Loss: 0.002150 | KL Loss: 0.008511
# TEST  [75/100] | Total Loss: 0.005759 | Recon Loss: 0.001687 | Koopman Loss: 0.003507 | Prediction Loss: 0.002147 | KL Loss: 0.010109
# --------------------------------------------------------------------------------------------------------------
# EPOCH [76/100] | Total Loss: 0.005801 | Recon Loss: 0.001670 | Koopman Loss: 0.003456 | Prediction Loss: 0.002115 | KL Loss: 0.010338
# TEST  [76/100] | Total Loss: 0.006731 | Recon Loss: 0.001651 | Koopman Loss: 0.003483 | Prediction Loss: 0.002094 | KL Loss: 0.013168
# --------------------------------------------------------------------------------------------------------------
# EPOCH [77/100] | Total Loss: 0.005609 | Recon Loss: 0.001645 | Koopman Loss: 0.003397 | Prediction Loss: 0.002076 | KL Loss: 0.009878
# TEST  [77/100] | Total Loss: 0.004814 | Recon Loss: 0.001628 | Koopman Loss: 0.003360 | Prediction Loss: 0.002064 | KL Loss: 0.007536
# --------------------------------------------------------------------------------------------------------------
# EPOCH [78/100] | Total Loss: 0.005115 | Recon Loss: 0.001629 | Koopman Loss: 0.003329 | Prediction Loss: 0.002046 | KL Loss: 0.008498
# TEST  [78/100] | Total Loss: 0.004724 | Recon Loss: 0.001600 | Koopman Loss: 0.003292 | Prediction Loss: 0.002025 | KL Loss: 0.007399
# --------------------------------------------------------------------------------------------------------------
# EPOCH [79/100] | Total Loss: 0.005340 | Recon Loss: 0.001601 | Koopman Loss: 0.003260 | Prediction Loss: 0.002002 | KL Loss: 0.009318
# TEST  [79/100] | Total Loss: 0.004830 | Recon Loss: 0.001602 | Koopman Loss: 0.003243 | Prediction Loss: 0.001989 | KL Loss: 0.007804
# --------------------------------------------------------------------------------------------------------------
# EPOCH [80/100] | Total Loss: 0.005163 | Recon Loss: 0.001581 | Koopman Loss: 0.003217 | Prediction Loss: 0.001963 | KL Loss: 0.008885
# TEST  [80/100] | Total Loss: 0.005112 | Recon Loss: 0.001557 | Koopman Loss: 0.003182 | Prediction Loss: 0.001959 | KL Loss: 0.008793
# --------------------------------------------------------------------------------------------------------------
# EPOCH [81/100] | Total Loss: 0.005437 | Recon Loss: 0.001563 | Koopman Loss: 0.003156 | Prediction Loss: 0.001928 | KL Loss: 0.009828
# TEST  [81/100] | Total Loss: 0.005177 | Recon Loss: 0.001550 | Koopman Loss: 0.003128 | Prediction Loss: 0.001921 | KL Loss: 0.009087
# --------------------------------------------------------------------------------------------------------------
# EPOCH [82/100] | Total Loss: 0.004831 | Recon Loss: 0.001538 | Koopman Loss: 0.003113 | Prediction Loss: 0.001897 | KL Loss: 0.008091
# TEST  [82/100] | Total Loss: 0.005345 | Recon Loss: 0.001515 | Koopman Loss: 0.003087 | Prediction Loss: 0.001883 | KL Loss: 0.009713
# --------------------------------------------------------------------------------------------------------------
# EPOCH [83/100] | Total Loss: 0.005316 | Recon Loss: 0.001526 | Koopman Loss: 0.003058 | Prediction Loss: 0.001864 | KL Loss: 0.009661
# TEST  [83/100] | Total Loss: 0.004916 | Recon Loss: 0.001507 | Koopman Loss: 0.003062 | Prediction Loss: 0.001864 | KL Loss: 0.008466
# --------------------------------------------------------------------------------------------------------------
# EPOCH [84/100] | Total Loss: 0.004803 | Recon Loss: 0.001493 | Koopman Loss: 0.003016 | Prediction Loss: 0.001834 | KL Loss: 0.008211
# TEST  [84/100] | Total Loss: 0.005273 | Recon Loss: 0.001473 | Koopman Loss: 0.002998 | Prediction Loss: 0.001819 | KL Loss: 0.009689
# --------------------------------------------------------------------------------------------------------------
# EPOCH [85/100] | Total Loss: 0.005482 | Recon Loss: 0.001479 | Koopman Loss: 0.002969 | Prediction Loss: 0.001794 | KL Loss: 0.010368
# TEST  [85/100] | Total Loss: 0.006104 | Recon Loss: 0.001474 | Koopman Loss: 0.002996 | Prediction Loss: 0.001771 | KL Loss: 0.012257
# --------------------------------------------------------------------------------------------------------------
# EPOCH [86/100] | Total Loss: 0.005129 | Recon Loss: 0.001459 | Koopman Loss: 0.002934 | Prediction Loss: 0.001766 | KL Loss: 0.009384
# TEST  [86/100] | Total Loss: 0.004996 | Recon Loss: 0.001440 | Koopman Loss: 0.002908 | Prediction Loss: 0.001762 | KL Loss: 0.009029
# --------------------------------------------------------------------------------------------------------------
# EPOCH [87/100] | Total Loss: 0.004821 | Recon Loss: 0.001434 | Koopman Loss: 0.002891 | Prediction Loss: 0.001731 | KL Loss: 0.008552
# TEST  [87/100] | Total Loss: 0.005028 | Recon Loss: 0.001424 | Koopman Loss: 0.002885 | Prediction Loss: 0.001712 | KL Loss: 0.009214
# --------------------------------------------------------------------------------------------------------------
# EPOCH [88/100] | Total Loss: 0.004887 | Recon Loss: 0.001416 | Koopman Loss: 0.002859 | Prediction Loss: 0.001700 | KL Loss: 0.008834
# TEST  [88/100] | Total Loss: 0.004550 | Recon Loss: 0.001395 | Koopman Loss: 0.002848 | Prediction Loss: 0.001684 | KL Loss: 0.007862
# --------------------------------------------------------------------------------------------------------------
# EPOCH [89/100] | Total Loss: 0.004787 | Recon Loss: 0.001392 | Koopman Loss: 0.002829 | Prediction Loss: 0.001669 | KL Loss: 0.008617
# TEST  [89/100] | Total Loss: 0.004509 | Recon Loss: 0.001378 | Koopman Loss: 0.002811 | Prediction Loss: 0.001653 | KL Loss: 0.007822
# --------------------------------------------------------------------------------------------------------------
# EPOCH [90/100] | Total Loss: 0.005029 | Recon Loss: 0.001374 | Koopman Loss: 0.002798 | Prediction Loss: 0.001636 | KL Loss: 0.009431
# TEST  [90/100] | Total Loss: 0.004272 | Recon Loss: 0.001363 | Koopman Loss: 0.002783 | Prediction Loss: 0.001615 | KL Loss: 0.007184
# --------------------------------------------------------------------------------------------------------------
# EPOCH [91/100] | Total Loss: 0.005152 | Recon Loss: 0.001355 | Koopman Loss: 0.002768 | Prediction Loss: 0.001605 | KL Loss: 0.009883
# TEST  [91/100] | Total Loss: 0.005226 | Recon Loss: 0.001346 | Koopman Loss: 0.002772 | Prediction Loss: 0.001587 | KL Loss: 0.010131
# --------------------------------------------------------------------------------------------------------------
# EPOCH [92/100] | Total Loss: 0.004993 | Recon Loss: 0.001333 | Koopman Loss: 0.002742 | Prediction Loss: 0.001571 | KL Loss: 0.009484
# TEST  [92/100] | Total Loss: 0.004919 | Recon Loss: 0.001317 | Koopman Loss: 0.002729 | Prediction Loss: 0.001564 | KL Loss: 0.009297
# --------------------------------------------------------------------------------------------------------------
# EPOCH [93/100] | Total Loss: 0.005143 | Recon Loss: 0.001315 | Koopman Loss: 0.002708 | Prediction Loss: 0.001542 | KL Loss: 0.010019
# TEST  [93/100] | Total Loss: 0.004856 | Recon Loss: 0.001303 | Koopman Loss: 0.002702 | Prediction Loss: 0.001538 | KL Loss: 0.009173
# --------------------------------------------------------------------------------------------------------------
# EPOCH [94/100] | Total Loss: 0.004982 | Recon Loss: 0.001294 | Koopman Loss: 0.002676 | Prediction Loss: 0.001512 | KL Loss: 0.009615
# TEST  [94/100] | Total Loss: 0.004747 | Recon Loss: 0.001283 | Koopman Loss: 0.002651 | Prediction Loss: 0.001493 | KL Loss: 0.008958
# --------------------------------------------------------------------------------------------------------------
# EPOCH [95/100] | Total Loss: 0.005079 | Recon Loss: 0.001272 | Koopman Loss: 0.002648 | Prediction Loss: 0.001481 | KL Loss: 0.009990
# TEST  [95/100] | Total Loss: 0.004456 | Recon Loss: 0.001257 | Koopman Loss: 0.002651 | Prediction Loss: 0.001469 | KL Loss: 0.008128
# --------------------------------------------------------------------------------------------------------------
# EPOCH [96/100] | Total Loss: 0.004583 | Recon Loss: 0.001247 | Koopman Loss: 0.002620 | Prediction Loss: 0.001443 | KL Loss: 0.008577
# TEST  [96/100] | Total Loss: 0.004744 | Recon Loss: 0.001231 | Koopman Loss: 0.002591 | Prediction Loss: 0.001431 | KL Loss: 0.009123
# --------------------------------------------------------------------------------------------------------------
# EPOCH [97/100] | Total Loss: 0.004794 | Recon Loss: 0.001224 | Koopman Loss: 0.002580 | Prediction Loss: 0.001415 | KL Loss: 0.009308
# TEST  [97/100] | Total Loss: 0.004576 | Recon Loss: 0.001223 | Koopman Loss: 0.002583 | Prediction Loss: 0.001406 | KL Loss: 0.008655
# --------------------------------------------------------------------------------------------------------------
# EPOCH [98/100] | Total Loss: 0.004676 | Recon Loss: 0.001202 | Koopman Loss: 0.002560 | Prediction Loss: 0.001387 | KL Loss: 0.009021
# TEST  [98/100] | Total Loss: 0.005006 | Recon Loss: 0.001196 | Koopman Loss: 0.002569 | Prediction Loss: 0.001375 | KL Loss: 0.010030
# --------------------------------------------------------------------------------------------------------------
# EPOCH [99/100] | Total Loss: 0.004565 | Recon Loss: 0.001180 | Koopman Loss: 0.002533 | Prediction Loss: 0.001354 | KL Loss: 0.008765
# TEST  [99/100] | Total Loss: 0.004509 | Recon Loss: 0.001169 | Koopman Loss: 0.002521 | Prediction Loss: 0.001338 | KL Loss: 0.008636
# --------------------------------------------------------------------------------------------------------------
# EPOCH [100/100] | Total Loss: 0.005005 | Recon Loss: 0.001156 | Koopman Loss: 0.002506 | Prediction Loss: 0.001326 | KL Loss: 0.010180
# TEST  [100/100] | Total Loss: 0.003974 | Recon Loss: 0.001137 | Koopman Loss: 0.002492 | Prediction Loss: 0.001307 | KL Loss: 0.007109
# --------------------------------------------------------------------------------------------------------------

# %%
# TODO: Explain the loss dynamics and justify your design choices

# %% [markdown]
# The total loss function is a weighted sum of the reconstruction error, the prediction error in Koopman space, the prediction error in the phase space and the variational loss (to make the prediction in the Koopman space as close as possible to $\mathcal{N}(0,1)$), i.e.,
#
# $$
# L = \alpha_{rec} *\Vert \varphi_\rho (g_\theta(x_k)) - x_k  \Vert + \alpha_{koop}* \Vert \mathbf{K_{\phi}} g_{\theta} ( x_k ) - g_{\theta} (x_{k+1})  \Vert + \alpha_{pred}*\Vert \varphi_{\rho} \left( \mathbf{K_{\phi}} g_{\theta} ( x_k )\right) - x_{k+1} \Vert + \alpha_{KL}KL.
# $$
#
# After several trials we decided to keep al coefficients equal to $0.33$, small variations have been tried but the losses tendancies were similar. We also frozen the gradients of the encoder for the prediction error in the phase space. With this configurations good results are attained but more options could be considered.
#
# After several attempts we decided to train for $100$ epochs because even when the losses are seen to fall near zero in early epochs, the results obtained in the verification part were badd for values such as $20$ or $30$.
#
# Overall, in the tendancy obtained for each loss term it is concluded that this configuration allows to obtain a consistent behavior in all of them and it is translated into a good dynamic prediction.

# %% [markdown]
# #### Verification

# %% [markdown]
# **Question 4.** : We want to ensure the Koopman operator is stable. This can be verified by checking whether its spectral radius $\rho(\mathbf{K})\le 1$. Plot the eigenvalues of the Koopman operator in order to verify the bound on its spectral radius. You can use the [`numpy.linalg.eig`](https://numpy.org/doc/stable/reference/generated/numpy.linalg.eig.html) function to retrieve the eigenvalues of a matrix.

# %%
# TODO: Check Koopman stability and plot the eigen values of the Koopman operator against the unit circle

eigenval, _ = np.linalg.eig(koopman_operator.weight_matrix.cpu().detach().numpy())

max_eigenvalue_magnitude = max(np.abs(eigenval))
print(f"The magnitude of the maximum eigenvalue is: {max_eigenvalue_magnitude}")

plt.figure(figsize=(7, 7))
plt.scatter(np.real(eigenval), np.imag(eigenval), color='blue')
theta = np.linspace(0, 2*np.pi, 100)
r = 1  # Radius
x1 = r * np.cos(theta)
x2 = r * np.sin(theta)
plt.plot(x1, x2, color='red', linestyle='--') # Unit circle
plt.xlabel('$\Re(\lambda)$')  # Real part
plt.ylabel('$\Im(\lambda)$')  # Imaginary part
plt.title('Eigenvalues in the Complex Plane')
plt.grid(True)
plt.axhline(y=0, color='k', linewidth=0.5)
plt.axvline(x=0, color='k', linewidth=0.5)
plt.show()
# Out:
# The magnitude of the maximum eigenvalue is: 0.9884635210037231

# %%
n_grid = 30
x1_min, x1_max = -2, 2
x2_min, x2_max = -2, 2

array_x1 = np.linspace(x1_min, x1_max, n_grid, dtype=np.float32)
array_x2 = np.linspace(x2_min, x2_max, n_grid, dtype=np.float32)
matrix_grid_x1, matrix_grid_x2 = np.meshgrid(array_x1, array_x2)

array3d_dynamics = np.zeros((n_grid, n_grid, 2), dtype=np.float32)

for i in range(n_grid):
    for j in range(n_grid):
        x1 = matrix_grid_x1[i, j]
        x2 = matrix_grid_x2[i, j]
        array3d_dynamics[i, j, :] = duffing(np.array([x1, x2]))

# Set evaluation mode
autoencoder.eval()
koopman_operator.eval()

array3d_dynamics_pred = np.zeros((n_grid, n_grid, 2), dtype=np.float32)

for i in range(n_grid):
    for j in range(n_grid):
        x1 = matrix_grid_x1[i, j]
        x2 = matrix_grid_x2[i, j]
        tensor2d_x = torch.tensor([[x1, x2]], dtype=torch.float32).to(device)
        tensor2d_observable = autoencoder.encoder(tensor2d_x)
        tensor2d_koopman_observable_next = koopman_operator(tensor2d_observable)
        tensor2d_predict_x_next = autoencoder.decoder(tensor2d_koopman_observable_next)
        array_x_next = tensor2d_predict_x_next.cpu().detach().numpy().ravel()

        # Here we compute a discretised version of the derivative thanks to the Koopman operator
        # and the learned encoder/decoder

        # (x_{k+1} - x_k) / \delta_t = f(x_k) is approximated by (f is duffing here)
        # (Decod(K(Encod(x_k))) - x_k) / \delta_t

        delta_time = (t_max / n_iter)
        array3d_dynamics_pred[i, j, :] = (array_x_next - [x1, x2]) / delta_time

# %%
fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(131)
ax.quiver(matrix_grid_x1,
          matrix_grid_x2,
          array3d_dynamics[:, :, 0],
          array3d_dynamics[:, :, 1], scale=10)
ax.set_title('True')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')

ax = fig.add_subplot(132)
ax.quiver(matrix_grid_x1,
          matrix_grid_x2,
          array3d_dynamics_pred[:, :, 0],
          array3d_dynamics_pred[:, :, 1], scale=10)

ax.set_title('Prediction')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')

# Compute the error
matrix_error = np.linalg.norm(array3d_dynamics - array3d_dynamics_pred, axis=2)
matrix_error_log = np.log10(matrix_error + 1e-10)

ax = fig.add_subplot(133)
cp = ax.contourf(matrix_grid_x1,
                 matrix_grid_x2,
                 matrix_error_log)

fig.colorbar(cp)
ax.set_title('Error in log scale')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
plt.show()

# %% [markdown]
# ### Continuous in time case
#
# Considering $x_k$ as the observation of a state at time $t = k \delta$, and $x_{k+1}$ the state at time $t+ \delta$, for $\delta \rightarrow 0$  it is also possible to define the continuous-time infinitesimal generator of the Koopman operator family as
#
# $$
# \mathcal{L} g (x_k)  = \lim_{\delta \rightarrow 0} \frac{\mathcal{K}g(x_k)- g(x_{k})}{\delta} = \frac{g \circ F (x_k) -x_k}{\delta}
# $$
#
# The pevious expression defines the Lie derivative, and for this reason $\mathcal{L}$ is known as the Lie operator. $\mathcal{L}$ describes the continuous dynamics of the observables in the Koopman space:
#
# $$
# \dot{g} (x) = \mathcal{L} g(x).
# $$
#
# The latter can be further expressed as:
#
# $$
# \dot{g} (x(t)) = \frac{dg(x)}{dt} = \nabla_x g \frac{dx}{dt} = \nabla_x g \cdot f(x) =\mathcal{L} g(x).
# $$
#
# Given $g_{\theta}$, $\varphi_{\rho}$ and $\mathbf{L}_{\phi}$ three parameterized functions, the following conditions hold:
#
# 1.   Reconstruction error
#      $$
#      \Vert \varphi_\rho (g_\theta(x)) - x  \Vert = 0
#      $$
# 2.   Prediction error in Koopman space
#      $$
#      \Vert \mathbf{L_{\phi}} g_{\theta} ( x ) - \nabla g_{\theta} \cdot f(x)  \Vert = 0
#      $$
# 3.   Prediction error in the phase space
#      $$
#      \Vert \varphi_{\rho} \left( \mathbf{L_{\phi}} g_{\theta} ( x )\right) - f(x) \Vert = 0
#      $$
#
# **Important Remark: As long as the system $f$ is known, the three errors can be computed without data belonging to trajectories.**

# %%
# Create a dataset for continuous Koopman
# with the same amount of points of the Discontinuous Koopman case
# But here no need to have continuous trajectories
matrix_x0 = (np.random.rand(n_initial_conditions * (n_iter - 1), 2) - 0.5) * 4
matrix_system_derivative_data = np.zeros(matrix_x0.shape)
for i in tqdm(range(matrix_x0.shape[0])):
    matrix_system_derivative_data[i, :] = duffing(matrix_x0[i, :])
# Out:
# 100%|██████████| 299940/299940 [00:02<00:00, 120588.96it/s]

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111)
ax.quiver(matrix_x0[::50, 0],
          matrix_x0[::50, 1],
          matrix_system_derivative_data[::50, 0] * 0.2,
          matrix_system_derivative_data[::50, 1] * 0.2, scale=10)
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
plt.show()

# %%
# create the models
feature_dim = 2  # dimension of the Duffing oscillator
hidden_layer = 5  # number of hidden layers in g (ENCODER) and \varphi (DECODER)
output_dim = 30  # dimension in Koopman space
batch_size = 2000  # data per batch

# %%
(matrix_x_data_train,
 matrix_x_data_test,
 matrix_x_next_data_train,
 matrix_x_next_data_test) = train_test_split(matrix_x0,
                                             matrix_system_derivative_data,
                                             test_size=0.2)

# Cast type to float32
matrix_x_data_train = matrix_x_data_train.astype(np.float32)
matrix_x_data_test = matrix_x_data_test.astype(np.float32)
matrix_x_next_data_train = matrix_x_next_data_train.astype(np.float32)
matrix_x_next_data_test = matrix_x_next_data_test.astype(np.float32)

print(matrix_x_data_train.shape,
      matrix_x_data_test.shape,
      matrix_x_next_data_train.shape,
      matrix_x_next_data_test.shape)

torch_dataset_train = TensorDataset(torch.from_numpy(matrix_x_data_train),
                                    torch.from_numpy(matrix_x_next_data_train))
torch_dataset_test = TensorDataset(torch.from_numpy(matrix_x_data_test),
                                   torch.from_numpy(matrix_x_next_data_test))

train_dataloader = DataLoader(torch_dataset_train,
                              batch_size=batch_size,
                              shuffle=True)
test_dataloader = DataLoader(torch_dataset_test,
                             batch_size=batch_size,
                             shuffle=True)
# Out:
# (239952, 2) (59988, 2) (239952, 2) (59988, 2)

# %%
class Encoder(nn.Module):
    def __init__(self, list_layer_dim):
        super().__init__()
        self.list_layer_dim = list_layer_dim
        self.list_FC = nn.ModuleList()
        for i in range(len(self.list_layer_dim) - 1):
            dim_input = self.list_layer_dim[i]
            dim_output = self.list_layer_dim[i + 1]
            self.list_FC.append(nn.Linear(dim_input, dim_output))

    def forward(self, tensor2d_x):
        for i in range(len(self.list_layer_dim) - 2):
            tensor2d_x = F.elu(self.list_FC[i](tensor2d_x))
        return self.list_FC[-1](tensor2d_x)

# %%
class Decoder(nn.Module):
    def __init__(self, list_layer_dim):
        super().__init__()
        self.list_layer_dim = list_layer_dim
        self.list_FC = nn.ModuleList()
        for i in range(len(self.list_layer_dim) - 1, 0, -1):
            dim_input = self.list_layer_dim[i]
            dim_output = self.list_layer_dim[i - 1]
            self.list_FC.append(nn.Linear(dim_input, dim_output))

    def forward(self, tensor2d_x):
        for i in range(len(self.list_layer_dim) - 2):
            tensor2d_x = F.elu(self.list_FC[i](tensor2d_x))
        return self.list_FC[-1](tensor2d_x)

# %%
class Autoencoder(nn.Module):
    def __init__(self, feature_dim, hidden_layer, output_dim):
        super().__init__()

        list_layer_dim = \
            [output_dim if i == hidden_layer
             else feature_dim + i * (output_dim - feature_dim) // hidden_layer
             for i in range(hidden_layer + 1)]

        self.encoder = Encoder(list_layer_dim)
        self.decoder = Decoder(list_layer_dim)

    def forward(self, tensor2d_x: torch.Tensor):
        tensor2d_x = self.encoder(tensor2d_x)
        return self.decoder(tensor2d_x)

# %% [markdown]
# The Lie operator must be defined such that it will be always stable by construction.
# To do that, we consider a matrix of parameters $\Psi \in \mathbb{R}^{m \times m}$ and a vector of parameters $\Gamma \in \mathbb{R}^m$. The resulting Lie operator will be of the form:
#
# $$
# \mathbf{L} = (\Psi - \Psi^T) - \text{diag}(\vert \Gamma \vert)
# $$
#
# with eigenvalues whose real part $\Re(\lambda) \leq 0$ .
# See https://math.stackexchange.com/questions/952233/eigenvalues-of-the-sum-of-a-diagonal-matrix-and-a-skew-symmetric-matrix for the mathematical proof (identify the matrix). Moreover if $\lambda \in \mathbb{C}$ is an eigenvalue of $\mathbf{L}$, it turns out that its real part $\Re(\lambda) \propto \Vert \Gamma \Vert$, i.e. it only depends on $\Gamma$.
#
# Remark: $- \text{diag}(\vert \Gamma \vert)$ is always a diagonal matrix with non-positive elements.

# %% [markdown]
# **Question 4.** : As you did for the discrete case, you now have to implement the `LieModule` module. It should have the form indicated above to guarantee $\Re(\lambda) \leq 0$. Check that the initialization fulfills this property.

# %%
class LieModule(nn.Module):
    def __init__(self, lie_operator_dim: int):
        super().__init__()
        self.lie_operator_dim = lie_operator_dim
        # Initialize Psi
        self.Psi = nn.Parameter(torch.randn(lie_operator_dim, lie_operator_dim))
        # Initialize Gamma
        self.Gamma = torch.nn.Parameter(torch.diag(torch.abs(torch.randn(output_dim))))

        self.lie_init = self.Psi - self.Psi.t() - self.Gamma


    def forward(self, tensor2d_x: torch.Tensor):
        if tensor2d_x.shape[1] != self.lie_operator_dim:
            sys.exit(f'Wrong Input Features. Please use tensor'
                     f' with {self.koopman_operator_dim} Input Features')

        # Compute the Lie operator L
        Psi_skew = self.Psi - self.Psi.t()
        L = Psi_skew - self.Gamma

        # Apply the Lie operator to the input tensor
        result = torch.mm(tensor2d_x, L)

        return result, L

# %%
autoencoder = Autoencoder(feature_dim, hidden_layer, output_dim).to(device)
lie_operator = LieModule(output_dim).to(device)
print(autoencoder)
# Out:
# Autoencoder(
#   (encoder): Encoder(
#     (list_FC): ModuleList(
#       (0): Linear(in_features=2, out_features=7, bias=True)
#       (1): Linear(in_features=7, out_features=13, bias=True)
#       (2): Linear(in_features=13, out_features=18, bias=True)
#       (3): Linear(in_features=18, out_features=24, bias=True)
#       (4): Linear(in_features=24, out_features=30, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (list_FC): ModuleList(
#       (0): Linear(in_features=30, out_features=24, bias=True)
#       (1): Linear(in_features=24, out_features=18, bias=True)
#       (2): Linear(in_features=18, out_features=13, bias=True)
#       (3): Linear(in_features=13, out_features=7, bias=True)
#       (4): Linear(in_features=7, out_features=2, bias=True)
#     )
#   )
# )

# %%
# Check that Re(lambda is lower or equal to 0 at init
eigenval, _ = np.linalg.eig(lie_operator.lie_init.cpu().detach().numpy())

fig, ax = plt.subplots(figsize=(10, 5))

# Plot the eigenvalues
ax.bar(np.arange(len(eigenval)), eigenval, width = 0.2, color='b')
ax.axhline(y=1, linestyle='--', color ='r')
ax.axhline(y=-1, linestyle='--', color ='r')
ax.set_xticks(ticks=np.arange(len(eigenval)))
ax.set_ylabel('$\lambda$')

plt.title('Eigenvalues')
plt.show()

# %% [markdown]
# Some tricks are needed to train. If the autoencoder and the Lie model are learned at the same speed, the training turns out to be highly unstable since the three loss functions have moving targets. For this reason, the Lie learning rate has been chosen smaller than the autoencoder one.

# %%
learning_rate_autoencoder = 0.0001
learning_rate_lie = 0.00001

optimiser_autoencoder = torch.optim.Adam(autoencoder.parameters(),
                                         lr=learning_rate_autoencoder,
                                         weight_decay=1e-3)
optimiser_lie = torch.optim.Adam(lie_operator.parameters(),
                                 lr=learning_rate_lie,
                                 weight_decay=1e-3)

# %% [markdown]
# A further loss is considered to stabilize the learning stage. The state $x$ belongs to a compact set, since it is the solution of a dissipative dynamical system. This is not true for $g(x)$ (we need to choose appropriate activation functions to have appropriate Liptchitz guarantees). To avoid discrepancies in magnitudes of $g_i(x)$, a regularization loss is added:
#
# $$
# \mu = \frac{1}{m} \sum_m g_i(x) = 0  \quad \text{and} \quad  \sigma = \left( \frac{1}{m}\sum_m(g_i(x)-\mu)^2 \right)^{1/2} = 1
# $$
#
# inspired by VAE.
#
# For the training to be smooth, the encoder parameters are not affected by the **prediction loss in phase space**. This is based on an empirical observation and is motivated by the fact that the encoder appears in the three losses and plays a competitive role against the decoder and the Lie model. This should not affect the results since the encoder remains coupled with the decoder in the **reconstruction loss** and with the Lie operator in the **prediction loss in Koopman space**.

# %% [markdown]
# **Question 5.** : Implement the loss function similarly to what you did for the **Question 2.** Note that here you should use the dynamics $f$ and its values for a set of points belonging to the domain $\left[ -2, 2 \right]^2$ while no data from proper **trajectories** are needed.

# %%
# Implement the loss function here
# See the training process below to identify the different components of the loss
def loss(tensor2d_x: torch.Tensor,
         tensor2d_x_next: torch.Tensor,
         tensor2d_decoded_x: torch.Tensor,
         tensor2d_observable: torch.Tensor,
         tensor2d_lie_observable_next: torch.Tensor,
         tensor2d_predict_x_next: torch.Tensor,
         tensor2d_jvp: torch.Tensor,
         lambda_recon: float = 0.33,
         lambda_lie: float = 0.33,
         lambda_prediction: float = 0.33,
         lambda_kl: float = 0.33):

    criterion = nn.MSELoss()

    # Reconstruction loss
    recon_loss = criterion(tensor2d_decoded_x, tensor2d_x)

    # Koopman loss
    lie_loss = criterion(tensor2d_lie_observable_next, tensor2d_jvp)

    # KL penalization
    kl_loss = torch.abs(torch.mean(tensor2d_observable)) + torch.abs(torch.std(tensor2d_observable) - 1)

    # Freeze encoder layers for prediction loss
    for p in autoencoder.encoder.parameters():
        p.requires_grad = False

    prediction_loss = criterion(tensor2d_predict_x_next, tensor2d_x_next)

    for p in autoencoder.encoder.parameters():
        p.requires_grad = True

    total_loss = lambda_recon * recon_loss + lambda_lie * lie_loss + lambda_prediction * prediction_loss + lambda_kl * kl_loss

    return total_loss, recon_loss, lie_loss, prediction_loss, kl_loss

# %% [markdown]
# **Since trajectories are not needed**, random states can be sampled from the system manifold $x_1 \in [-2, 2]$, $x_2 \in [-2, 2]$.

# %%
import matplotlib.pyplot as plt
import json

# Hyperparameters
n_batch = len(train_dataloader)
n_epoch = 100
verbose = True
eval_interval = 1  # Evaluate every epoch

# Loss component storage
losses_log = {
    'train': {'total': [], 'rec': [], 'lie': [], 'pred': [], 'kl': []},
    'test':  {'total': [], 'rec': [], 'lie': [], 'pred': [], 'kl': []}
}

for epoch in range(n_epoch):
    autoencoder.train()
    lie_operator.train()

    total_train_loss = 0
    total_recon_loss = 0
    total_lie_loss = 0
    total_prediction_loss = 0
    total_kl_loss = 0

    for tensor2d_batch_x, tensor2d_batch_x_next in train_dataloader:
        tensor2d_batch_x = tensor2d_batch_x.to(device)
        tensor2d_batch_x_next = tensor2d_batch_x_next.to(device)

        optimiser_autoencoder.zero_grad()
        optimiser_lie.zero_grad()

        # Forward pass:
        # Compute observables and Jacobian-vector product using autograd.functional.jvp
        tensor2d_observable, tensor2d_jvp = autograd.functional.jvp(
            autoencoder.encoder,
            tensor2d_batch_x,
            tensor2d_batch_x_next,
            create_graph=True
        )
        tensor2d_decoded_x = autoencoder.decoder(tensor2d_observable)
        tensor2d_lie_observable_next, lie_matrix = lie_operator(tensor2d_observable)
        tensor2d_predict_x_next = autoencoder.decoder(tensor2d_lie_observable_next)

        # Compute all loss components (make sure your loss function matches the expected arguments)
        tensor_loss_val, r_error, lie_error, pred_error, kl_error = loss(
            tensor2d_x=tensor2d_batch_x,
            tensor2d_x_next=tensor2d_batch_x_next,
            tensor2d_decoded_x=tensor2d_decoded_x,
            tensor2d_observable=tensor2d_observable,
            tensor2d_lie_observable_next=tensor2d_lie_observable_next,
            tensor2d_predict_x_next=tensor2d_predict_x_next,
            tensor2d_jvp=tensor2d_jvp
        )

        # Backpropagation
        tensor_loss_val.backward()
        optimiser_autoencoder.step()
        optimiser_lie.step()

        # Accumulate training losses
        total_train_loss += tensor_loss_val.item()
        total_recon_loss += r_error.item()
        total_lie_loss += lie_error.item()
        total_prediction_loss += pred_error.item()
        total_kl_loss += kl_error.item()

    # Average the losses per batch
    avg_total_loss = total_train_loss / n_batch
    avg_recon_loss = total_recon_loss / n_batch
    avg_lie_loss = total_lie_loss / n_batch
    avg_pred_loss = total_prediction_loss / n_batch
    avg_kl_loss = total_kl_loss / n_batch

    # Store training losses for this epoch
    losses_log['train']['total'].append(avg_total_loss)
    losses_log['train']['rec'].append(avg_recon_loss)
    losses_log['train']['lie'].append(avg_lie_loss)
    losses_log['train']['pred'].append(avg_pred_loss)
    losses_log['train']['kl'].append(avg_kl_loss)

    # Verbose output for training
    if verbose:
        if avg_kl_loss > 0:
            print(f"EPOCH [{epoch+1}/{n_epoch}] | Total Loss: {avg_total_loss:.6f} | Recon Loss: {avg_recon_loss:.6f} | Lie Loss: {avg_lie_loss:.6f} | Prediction Loss: {avg_pred_loss:.6f} | KL Loss: {avg_kl_loss:.6f}")
        else:
            print(f"EPOCH [{epoch+1}/{n_epoch}] | Total Loss: {avg_total_loss:.6f} | Recon Loss: {avg_recon_loss:.6f} | Lie Loss: {avg_lie_loss:.6f} | Prediction Loss: {avg_pred_loss:.6f}")

    # Validation step
    if epoch % eval_interval == 0 or epoch == n_epoch - 1:
        autoencoder.eval()
        lie_operator.eval()

        total_test_loss = 0
        total_test_recon_loss = 0
        total_test_lie_loss = 0
        total_test_pred_loss = 0
        total_test_kl_loss = 0
        test_batches = 0

        with torch.no_grad():
            for tensor2d_batch_x, tensor2d_batch_x_next in test_dataloader:
                tensor2d_batch_x = tensor2d_batch_x.to(device)
                tensor2d_batch_x_next = tensor2d_batch_x_next.to(device)

                tensor2d_observable, tensor2d_jvp = autograd.functional.jvp(
                    autoencoder.encoder,
                    tensor2d_batch_x,
                    tensor2d_batch_x_next,
                    create_graph=False
                )
                tensor2d_decoded_x = autoencoder.decoder(tensor2d_observable)
                tensor2d_lie_observable_next, lie_matrix = lie_operator(tensor2d_observable)
                tensor2d_predict_x_next = autoencoder.decoder(tensor2d_lie_observable_next)

                tensor_loss_val, r_error, lie_error, pred_error, kl_error = loss(
                    tensor2d_x=tensor2d_batch_x,
                    tensor2d_x_next=tensor2d_batch_x_next,
                    tensor2d_decoded_x=tensor2d_decoded_x,
                    tensor2d_observable=tensor2d_observable,
                    tensor2d_lie_observable_next=tensor2d_lie_observable_next,
                    tensor2d_predict_x_next=tensor2d_predict_x_next,
                    tensor2d_jvp=tensor2d_jvp
                )

                total_test_loss += tensor_loss_val.item()
                total_test_recon_loss += r_error.item()
                total_test_lie_loss += lie_error.item()
                total_test_pred_loss += pred_error.item()
                total_test_kl_loss += kl_error.item()
                test_batches += 1

        # Average test losses per batch
        avg_test_loss = total_test_loss / test_batches
        avg_test_recon = total_test_recon_loss / test_batches
        avg_test_lie = total_test_lie_loss / test_batches
        avg_test_pred = total_test_pred_loss / test_batches
        avg_test_kl = total_test_kl_loss / test_batches

        losses_log['test']['total'].append(avg_test_loss)
        losses_log['test']['rec'].append(avg_test_recon)
        losses_log['test']['lie'].append(avg_test_lie)
        losses_log['test']['pred'].append(avg_test_pred)
        losses_log['test']['kl'].append(avg_test_kl)

        # Verbose output for test evaluation
        if verbose:
            if avg_test_kl > 0:
                print(f"TEST  [{epoch+1}/{n_epoch}] | Total Loss: {avg_test_loss:.6f} | Recon Loss: {avg_test_recon:.6f} | Lie Loss: {avg_test_lie:.6f} | Prediction Loss: {avg_test_pred:.6f} | KL Loss: {avg_test_kl:.6f}")
            else:
                print(f"TEST  [{epoch+1}/{n_epoch}] | Total Loss: {avg_test_loss:.6f} | Recon Loss: {avg_test_recon:.6f} | Lie Loss: {avg_test_lie:.6f} | Prediction Loss: {avg_test_pred:.6f}")
            print('-' * 110)

# Plot losses
loss_names = ['total', 'rec', 'lie', 'pred', 'kl']
titles = ['Total Loss', 'Reconstruction Loss', 'Lie Loss', 'Prediction Loss', 'KL Loss']

# If KL losses are zero, you might want to exclude that plot
if not any(losses_log['train']['kl']) and not any(losses_log['test']['kl']):
    loss_names = loss_names[:-1]
    fig, axs = plt.subplots(1, 4, figsize=(15, 5), sharex=True, sharey=True)
else:
    fig, axs = plt.subplots(1, 5, figsize=(15, 5), sharex=True, sharey=True)
axs = axs.flatten()

for i, loss_key in enumerate(loss_names):
    axs[i].plot(losses_log['train'][loss_key], label='Train')
    axs[i].plot(losses_log['test'][loss_key], label='Test', linestyle='--')
    axs[i].set_title(titles[i])
    axs[i].set_xlabel('Epoch')
    axs[i].legend()
    axs[i].grid(True)

plt.tight_layout()
plt.show()

# Save logs as JSON
with open('losses_log.json', 'w') as f:
    json.dump(losses_log, f)
# Out:
# EPOCH [1/100] | Total Loss: 1.672780 | Recon Loss: 1.333604 | Lie Loss: 0.500045 | Prediction Loss: 2.345341 | KL Loss: 0.890039
# TEST  [1/100] | Total Loss: 1.544739 | Recon Loss: 1.317196 | Lie Loss: 0.353755 | Prediction Loss: 2.114790 | KL Loss: 0.895287
# --------------------------------------------------------------------------------------------------------------
# EPOCH [2/100] | Total Loss: 1.432718 | Recon Loss: 1.259737 | Lie Loss: 0.284707 | Prediction Loss: 1.894678 | KL Loss: 0.902449
# TEST  [2/100] | Total Loss: 1.348770 | Recon Loss: 1.176711 | Lie Loss: 0.240908 | Prediction Loss: 1.763233 | KL Loss: 0.906329
# --------------------------------------------------------------------------------------------------------------
# EPOCH [3/100] | Total Loss: 1.234459 | Recon Loss: 1.023824 | Lie Loss: 0.256387 | Prediction Loss: 1.559510 | KL Loss: 0.901065
# TEST  [3/100] | Total Loss: 1.129462 | Recon Loss: 0.865533 | Lie Loss: 0.278089 | Prediction Loss: 1.386813 | KL Loss: 0.892178
# --------------------------------------------------------------------------------------------------------------
# EPOCH [4/100] | Total Loss: 1.026433 | Recon Loss: 0.749759 | Lie Loss: 0.265231 | Prediction Loss: 1.211923 | KL Loss: 0.883489
# TEST  [4/100] | Total Loss: 0.951006 | Recon Loss: 0.658933 | Lie Loss: 0.238726 | Prediction Loss: 1.107818 | KL Loss: 0.876361
# --------------------------------------------------------------------------------------------------------------
# EPOCH [5/100] | Total Loss: 0.884887 | Recon Loss: 0.580623 | Lie Loss: 0.204665 | Prediction Loss: 1.023809 | KL Loss: 0.872379
# TEST  [5/100] | Total Loss: 0.833547 | Recon Loss: 0.494882 | Lie Loss: 0.174826 | Prediction Loss: 0.987440 | KL Loss: 0.868753
# --------------------------------------------------------------------------------------------------------------
# EPOCH [6/100] | Total Loss: 0.772880 | Recon Loss: 0.382958 | Lie Loss: 0.156137 | Prediction Loss: 0.939767 | KL Loss: 0.863198
# TEST  [6/100] | Total Loss: 0.723473 | Recon Loss: 0.269300 | Lie Loss: 0.142458 | Prediction Loss: 0.924021 | KL Loss: 0.856564
# --------------------------------------------------------------------------------------------------------------
# EPOCH [7/100] | Total Loss: 0.673453 | Recon Loss: 0.188112 | Lie Loss: 0.128273 | Prediction Loss: 0.874469 | KL Loss: 0.849912
# TEST  [7/100] | Total Loss: 0.636399 | Recon Loss: 0.131816 | Lie Loss: 0.112704 | Prediction Loss: 0.839469 | KL Loss: 0.844495
# --------------------------------------------------------------------------------------------------------------
# EPOCH [8/100] | Total Loss: 0.588261 | Recon Loss: 0.106542 | Lie Loss: 0.098201 | Prediction Loss: 0.736145 | KL Loss: 0.841721
# TEST  [8/100] | Total Loss: 0.546709 | Recon Loss: 0.089610 | Lie Loss: 0.087004 | Prediction Loss: 0.641176 | KL Loss: 0.838905
# --------------------------------------------------------------------------------------------------------------
# EPOCH [9/100] | Total Loss: 0.497763 | Recon Loss: 0.080854 | Lie Loss: 0.079377 | Prediction Loss: 0.511494 | KL Loss: 0.836648
# TEST  [9/100] | Total Loss: 0.463579 | Recon Loss: 0.073469 | Lie Loss: 0.073384 | Prediction Loss: 0.424268 | KL Loss: 0.833666
# --------------------------------------------------------------------------------------------------------------
# EPOCH [10/100] | Total Loss: 0.437247 | Recon Loss: 0.066463 | Lie Loss: 0.069129 | Prediction Loss: 0.358805 | KL Loss: 0.830594
# TEST  [10/100] | Total Loss: 0.422015 | Recon Loss: 0.060322 | Lie Loss: 0.065506 | Prediction Loss: 0.325872 | KL Loss: 0.827135
# --------------------------------------------------------------------------------------------------------------
# EPOCH [11/100] | Total Loss: 0.407001 | Recon Loss: 0.055037 | Lie Loss: 0.063535 | Prediction Loss: 0.290847 | KL Loss: 0.823916
# TEST  [11/100] | Total Loss: 0.397783 | Recon Loss: 0.050712 | Lie Loss: 0.061915 | Prediction Loss: 0.272613 | KL Loss: 0.820163
# --------------------------------------------------------------------------------------------------------------
# EPOCH [12/100] | Total Loss: 0.386834 | Recon Loss: 0.046905 | Lie Loss: 0.060985 | Prediction Loss: 0.247876 | KL Loss: 0.816459
# TEST  [12/100] | Total Loss: 0.380092 | Recon Loss: 0.043910 | Lie Loss: 0.060247 | Prediction Loss: 0.235270 | KL Loss: 0.812369
# --------------------------------------------------------------------------------------------------------------
# EPOCH [13/100] | Total Loss: 0.370684 | Recon Loss: 0.040931 | Lie Loss: 0.060178 | Prediction Loss: 0.213541 | KL Loss: 0.808635
# TEST  [13/100] | Total Loss: 0.364761 | Recon Loss: 0.038621 | Lie Loss: 0.059890 | Prediction Loss: 0.202505 | KL Loss: 0.804320
# --------------------------------------------------------------------------------------------------------------
# EPOCH [14/100] | Total Loss: 0.357048 | Recon Loss: 0.036241 | Lie Loss: 0.060250 | Prediction Loss: 0.185008 | KL Loss: 0.800465
# TEST  [14/100] | Total Loss: 0.351614 | Recon Loss: 0.034482 | Lie Loss: 0.060374 | Prediction Loss: 0.174834 | KL Loss: 0.795808
# --------------------------------------------------------------------------------------------------------------
# EPOCH [15/100] | Total Loss: 0.344947 | Recon Loss: 0.032409 | Lie Loss: 0.060822 | Prediction Loss: 0.160437 | KL Loss: 0.791626
# TEST  [15/100] | Total Loss: 0.340132 | Recon Loss: 0.030923 | Lie Loss: 0.061218 | Prediction Loss: 0.151729 | KL Loss: 0.786833
# --------------------------------------------------------------------------------------------------------------
# EPOCH [16/100] | Total Loss: 0.334234 | Recon Loss: 0.029144 | Lie Loss: 0.061756 | Prediction Loss: 0.139613 | KL Loss: 0.782317
# TEST  [16/100] | Total Loss: 0.329675 | Recon Loss: 0.027862 | Lie Loss: 0.062203 | Prediction Loss: 0.131498 | KL Loss: 0.777451
# --------------------------------------------------------------------------------------------------------------
# EPOCH [17/100] | Total Loss: 0.324241 | Recon Loss: 0.026290 | Lie Loss: 0.062839 | Prediction Loss: 0.120391 | KL Loss: 0.773029
# TEST  [17/100] | Total Loss: 0.320265 | Recon Loss: 0.025122 | Lie Loss: 0.063259 | Prediction Loss: 0.114324 | KL Loss: 0.767796
# --------------------------------------------------------------------------------------------------------------
# EPOCH [18/100] | Total Loss: 0.315513 | Recon Loss: 0.023692 | Lie Loss: 0.064046 | Prediction Loss: 0.105262 | KL Loss: 0.763100
# TEST  [18/100] | Total Loss: 0.311544 | Recon Loss: 0.022681 | Lie Loss: 0.064549 | Prediction Loss: 0.098851 | KL Loss: 0.757993
# --------------------------------------------------------------------------------------------------------------
# EPOCH [19/100] | Total Loss: 0.307264 | Recon Loss: 0.021359 | Lie Loss: 0.065257 | Prediction Loss: 0.091161 | KL Loss: 0.753327
# TEST  [19/100] | Total Loss: 0.303608 | Recon Loss: 0.020438 | Lie Loss: 0.065746 | Prediction Loss: 0.085718 | KL Loss: 0.748123
# --------------------------------------------------------------------------------------------------------------
# EPOCH [20/100] | Total Loss: 0.299576 | Recon Loss: 0.019233 | Lie Loss: 0.066468 | Prediction Loss: 0.078843 | KL Loss: 0.743262
# TEST  [20/100] | Total Loss: 0.296211 | Recon Loss: 0.018359 | Lie Loss: 0.067047 | Prediction Loss: 0.074543 | KL Loss: 0.737661
# --------------------------------------------------------------------------------------------------------------
# EPOCH [21/100] | Total Loss: 0.292532 | Recon Loss: 0.017271 | Lie Loss: 0.067780 | Prediction Loss: 0.069037 | KL Loss: 0.732371
# TEST  [21/100] | Total Loss: 0.290398 | Recon Loss: 0.016511 | Lie Loss: 0.068460 | Prediction Loss: 0.068491 | KL Loss: 0.726533
# --------------------------------------------------------------------------------------------------------------
# EPOCH [22/100] | Total Loss: 0.285950 | Recon Loss: 0.015518 | Lie Loss: 0.069118 | Prediction Loss: 0.060715 | KL Loss: 0.721164
# TEST  [22/100] | Total Loss: 0.283530 | Recon Loss: 0.014847 | Lie Loss: 0.069712 | Prediction Loss: 0.059219 | KL Loss: 0.715405
# --------------------------------------------------------------------------------------------------------------
# EPOCH [23/100] | Total Loss: 0.279732 | Recon Loss: 0.013986 | Lie Loss: 0.070373 | Prediction Loss: 0.053225 | KL Loss: 0.710090
# TEST  [23/100] | Total Loss: 0.276909 | Recon Loss: 0.013399 | Lie Loss: 0.070822 | Prediction Loss: 0.050583 | KL Loss: 0.704313
# --------------------------------------------------------------------------------------------------------------
# EPOCH [24/100] | Total Loss: 0.273817 | Recon Loss: 0.012620 | Lie Loss: 0.071611 | Prediction Loss: 0.046765 | KL Loss: 0.698753
# TEST  [24/100] | Total Loss: 0.270957 | Recon Loss: 0.012112 | Lie Loss: 0.072104 | Prediction Loss: 0.044206 | KL Loss: 0.692659
# --------------------------------------------------------------------------------------------------------------
# EPOCH [25/100] | Total Loss: 0.268157 | Recon Loss: 0.011417 | Lie Loss: 0.072881 | Prediction Loss: 0.041415 | KL Loss: 0.686884
# TEST  [25/100] | Total Loss: 0.266523 | Recon Loss: 0.010966 | Lie Loss: 0.073340 | Prediction Loss: 0.042858 | KL Loss: 0.680483
# --------------------------------------------------------------------------------------------------------------
# EPOCH [26/100] | Total Loss: 0.262727 | Recon Loss: 0.010346 | Lie Loss: 0.074164 | Prediction Loss: 0.037011 | KL Loss: 0.674619
# TEST  [26/100] | Total Loss: 0.260181 | Recon Loss: 0.009959 | Lie Loss: 0.074640 | Prediction Loss: 0.035800 | KL Loss: 0.668026
# --------------------------------------------------------------------------------------------------------------
# EPOCH [27/100] | Total Loss: 0.257156 | Recon Loss: 0.009411 | Lie Loss: 0.075452 | Prediction Loss: 0.032492 | KL Loss: 0.661903
# TEST  [27/100] | Total Loss: 0.254460 | Recon Loss: 0.009063 | Lie Loss: 0.075974 | Prediction Loss: 0.031000 | KL Loss: 0.655053
# --------------------------------------------------------------------------------------------------------------
# EPOCH [28/100] | Total Loss: 0.251880 | Recon Loss: 0.008577 | Lie Loss: 0.076781 | Prediction Loss: 0.029450 | KL Loss: 0.648464
# TEST  [28/100] | Total Loss: 0.248997 | Recon Loss: 0.008286 | Lie Loss: 0.077311 | Prediction Loss: 0.027799 | KL Loss: 0.641139
# --------------------------------------------------------------------------------------------------------------
# EPOCH [29/100] | Total Loss: 0.246464 | Recon Loss: 0.007858 | Lie Loss: 0.078142 | Prediction Loss: 0.026403 | KL Loss: 0.634459
# TEST  [29/100] | Total Loss: 0.243534 | Recon Loss: 0.007593 | Lie Loss: 0.078652 | Prediction Loss: 0.024826 | KL Loss: 0.626912
# --------------------------------------------------------------------------------------------------------------
# EPOCH [30/100] | Total Loss: 0.240993 | Recon Loss: 0.007219 | Lie Loss: 0.079524 | Prediction Loss: 0.023801 | KL Loss: 0.619736
# TEST  [30/100] | Total Loss: 0.238190 | Recon Loss: 0.006994 | Lie Loss: 0.080081 | Prediction Loss: 0.022861 | KL Loss: 0.611851
# --------------------------------------------------------------------------------------------------------------
# EPOCH [31/100] | Total Loss: 0.235416 | Recon Loss: 0.006657 | Lie Loss: 0.080961 | Prediction Loss: 0.021615 | KL Loss: 0.604149
# TEST  [31/100] | Total Loss: 0.232399 | Recon Loss: 0.006459 | Lie Loss: 0.081518 | Prediction Loss: 0.020515 | KL Loss: 0.595748
# --------------------------------------------------------------------------------------------------------------
# EPOCH [32/100] | Total Loss: 0.229950 | Recon Loss: 0.006167 | Lie Loss: 0.082434 | Prediction Loss: 0.020349 | KL Loss: 0.587867
# TEST  [32/100] | Total Loss: 0.226957 | Recon Loss: 0.005996 | Lie Loss: 0.083004 | Prediction Loss: 0.019386 | KL Loss: 0.579361
# --------------------------------------------------------------------------------------------------------------
# EPOCH [33/100] | Total Loss: 0.224149 | Recon Loss: 0.005733 | Lie Loss: 0.083907 | Prediction Loss: 0.018446 | KL Loss: 0.571153
# TEST  [33/100] | Total Loss: 0.221360 | Recon Loss: 0.005621 | Lie Loss: 0.084483 | Prediction Loss: 0.018585 | KL Loss: 0.562098
# --------------------------------------------------------------------------------------------------------------
# EPOCH [34/100] | Total Loss: 0.218270 | Recon Loss: 0.005348 | Lie Loss: 0.085417 | Prediction Loss: 0.017144 | KL Loss: 0.553517
# TEST  [34/100] | Total Loss: 0.214984 | Recon Loss: 0.005230 | Lie Loss: 0.085955 | Prediction Loss: 0.016158 | KL Loss: 0.544126
# --------------------------------------------------------------------------------------------------------------
# EPOCH [35/100] | Total Loss: 0.212204 | Recon Loss: 0.005009 | Lie Loss: 0.086925 | Prediction Loss: 0.015938 | KL Loss: 0.535169
# TEST  [35/100] | Total Loss: 0.208865 | Recon Loss: 0.004905 | Lie Loss: 0.087465 | Prediction Loss: 0.015387 | KL Loss: 0.525168
# --------------------------------------------------------------------------------------------------------------
# EPOCH [36/100] | Total Loss: 0.205794 | Recon Loss: 0.004702 | Lie Loss: 0.088478 | Prediction Loss: 0.014922 | KL Loss: 0.515517
# TEST  [36/100] | Total Loss: 0.202272 | Recon Loss: 0.004617 | Lie Loss: 0.088991 | Prediction Loss: 0.014441 | KL Loss: 0.504896
# --------------------------------------------------------------------------------------------------------------
# EPOCH [37/100] | Total Loss: 0.199019 | Recon Loss: 0.004432 | Lie Loss: 0.090051 | Prediction Loss: 0.014156 | KL Loss: 0.494451
# TEST  [37/100] | Total Loss: 0.195566 | Recon Loss: 0.004347 | Lie Loss: 0.090648 | Prediction Loss: 0.014557 | KL Loss: 0.483071
# --------------------------------------------------------------------------------------------------------------
# EPOCH [38/100] | Total Loss: 0.191899 | Recon Loss: 0.004195 | Lie Loss: 0.091661 | Prediction Loss: 0.013615 | KL Loss: 0.472040
# TEST  [38/100] | Total Loss: 0.187800 | Recon Loss: 0.004126 | Lie Loss: 0.092171 | Prediction Loss: 0.012740 | KL Loss: 0.460053
# --------------------------------------------------------------------------------------------------------------
# EPOCH [39/100] | Total Loss: 0.184382 | Recon Loss: 0.003985 | Lie Loss: 0.093228 | Prediction Loss: 0.012940 | KL Loss: 0.448581
# TEST  [39/100] | Total Loss: 0.180579 | Recon Loss: 0.003961 | Lie Loss: 0.093686 | Prediction Loss: 0.013538 | KL Loss: 0.436025
# --------------------------------------------------------------------------------------------------------------
# EPOCH [40/100] | Total Loss: 0.176392 | Recon Loss: 0.003807 | Lie Loss: 0.094737 | Prediction Loss: 0.012319 | KL Loss: 0.423656
# TEST  [40/100] | Total Loss: 0.171890 | Recon Loss: 0.003765 | Lie Loss: 0.095210 | Prediction Loss: 0.011747 | KL Loss: 0.410157
# --------------------------------------------------------------------------------------------------------------
# EPOCH [41/100] | Total Loss: 0.168021 | Recon Loss: 0.003649 | Lie Loss: 0.096211 | Prediction Loss: 0.012307 | KL Loss: 0.396988
# TEST  [41/100] | Total Loss: 0.163316 | Recon Loss: 0.003609 | Lie Loss: 0.096647 | Prediction Loss: 0.011836 | KL Loss: 0.382804
# --------------------------------------------------------------------------------------------------------------
# EPOCH [42/100] | Total Loss: 0.158995 | Recon Loss: 0.003512 | Lie Loss: 0.097594 | Prediction Loss: 0.011592 | KL Loss: 0.369104
# TEST  [42/100] | Total Loss: 0.154007 | Recon Loss: 0.003482 | Lie Loss: 0.097891 | Prediction Loss: 0.011019 | KL Loss: 0.354295
# --------------------------------------------------------------------------------------------------------------
# EPOCH [43/100] | Total Loss: 0.149565 | Recon Loss: 0.003391 | Lie Loss: 0.098799 | Prediction Loss: 0.011412 | KL Loss: 0.339625
# TEST  [43/100] | Total Loss: 0.144784 | Recon Loss: 0.003375 | Lie Loss: 0.099067 | Prediction Loss: 0.012542 | KL Loss: 0.323754
# --------------------------------------------------------------------------------------------------------------
# EPOCH [44/100] | Total Loss: 0.139501 | Recon Loss: 0.003291 | Lie Loss: 0.099872 | Prediction Loss: 0.011231 | KL Loss: 0.308337
# TEST  [44/100] | Total Loss: 0.135555 | Recon Loss: 0.003323 | Lie Loss: 0.100004 | Prediction Loss: 0.015967 | KL Loss: 0.291481
# --------------------------------------------------------------------------------------------------------------
# EPOCH [45/100] | Total Loss: 0.128763 | Recon Loss: 0.003205 | Lie Loss: 0.100719 | Prediction Loss: 0.010717 | KL Loss: 0.275551
# TEST  [45/100] | Total Loss: 0.122778 | Recon Loss: 0.003187 | Lie Loss: 0.100739 | Prediction Loss: 0.009963 | KL Loss: 0.258166
# --------------------------------------------------------------------------------------------------------------
# EPOCH [46/100] | Total Loss: 0.117550 | Recon Loss: 0.003113 | Lie Loss: 0.101350 | Prediction Loss: 0.010826 | KL Loss: 0.240922
# TEST  [46/100] | Total Loss: 0.111943 | Recon Loss: 0.003104 | Lie Loss: 0.101259 | Prediction Loss: 0.012135 | KL Loss: 0.222722
# --------------------------------------------------------------------------------------------------------------
# EPOCH [47/100] | Total Loss: 0.105896 | Recon Loss: 0.003037 | Lie Loss: 0.101783 | Prediction Loss: 0.010501 | KL Loss: 0.205575
# TEST  [47/100] | Total Loss: 0.099351 | Recon Loss: 0.003008 | Lie Loss: 0.101561 | Prediction Loss: 0.009104 | KL Loss: 0.187390
# --------------------------------------------------------------------------------------------------------------
# EPOCH [48/100] | Total Loss: 0.093721 | Recon Loss: 0.002939 | Lie Loss: 0.101987 | Prediction Loss: 0.009732 | KL Loss: 0.169344
# TEST  [48/100] | Total Loss: 0.086881 | Recon Loss: 0.002901 | Lie Loss: 0.101630 | Prediction Loss: 0.008756 | KL Loss: 0.149989
# --------------------------------------------------------------------------------------------------------------
# EPOCH [49/100] | Total Loss: 0.081293 | Recon Loss: 0.002828 | Lie Loss: 0.101991 | Prediction Loss: 0.010067 | KL Loss: 0.131456
# TEST  [49/100] | Total Loss: 0.074569 | Recon Loss: 0.002790 | Lie Loss: 0.101539 | Prediction Loss: 0.009512 | KL Loss: 0.112126
# --------------------------------------------------------------------------------------------------------------
# EPOCH [50/100] | Total Loss: 0.068312 | Recon Loss: 0.002698 | Lie Loss: 0.101755 | Prediction Loss: 0.009423 | KL Loss: 0.093129
# TEST  [50/100] | Total Loss: 0.061086 | Recon Loss: 0.002656 | Lie Loss: 0.101133 | Prediction Loss: 0.008175 | KL Loss: 0.073144
# --------------------------------------------------------------------------------------------------------------
# EPOCH [51/100] | Total Loss: 0.054839 | Recon Loss: 0.002574 | Lie Loss: 0.101301 | Prediction Loss: 0.009004 | KL Loss: 0.053301
# TEST  [51/100] | Total Loss: 0.048614 | Recon Loss: 0.002523 | Lie Loss: 0.100624 | Prediction Loss: 0.012144 | KL Loss: 0.032024
# --------------------------------------------------------------------------------------------------------------
# EPOCH [52/100] | Total Loss: 0.041572 | Recon Loss: 0.002462 | Lie Loss: 0.100150 | Prediction Loss: 0.009385 | KL Loss: 0.013978
# TEST  [52/100] | Total Loss: 0.036350 | Recon Loss: 0.002467 | Lie Loss: 0.096314 | Prediction Loss: 0.007695 | KL Loss: 0.003677
# --------------------------------------------------------------------------------------------------------------
# EPOCH [53/100] | Total Loss: 0.035039 | Recon Loss: 0.002311 | Lie Loss: 0.091942 | Prediction Loss: 0.008842 | KL Loss: 0.003085
# TEST  [53/100] | Total Loss: 0.033067 | Recon Loss: 0.002250 | Lie Loss: 0.086481 | Prediction Loss: 0.007549 | KL Loss: 0.003924
# --------------------------------------------------------------------------------------------------------------
# EPOCH [54/100] | Total Loss: 0.031923 | Recon Loss: 0.002164 | Lie Loss: 0.083482 | Prediction Loss: 0.008205 | KL Loss: 0.002885
# TEST  [54/100] | Total Loss: 0.030303 | Recon Loss: 0.002163 | Lie Loss: 0.079418 | Prediction Loss: 0.007264 | KL Loss: 0.002982
# --------------------------------------------------------------------------------------------------------------
# EPOCH [55/100] | Total Loss: 0.029297 | Recon Loss: 0.002064 | Lie Loss: 0.076475 | Prediction Loss: 0.007437 | KL Loss: 0.002802
# TEST  [55/100] | Total Loss: 0.028378 | Recon Loss: 0.002008 | Lie Loss: 0.073078 | Prediction Loss: 0.008514 | KL Loss: 0.002394
# --------------------------------------------------------------------------------------------------------------
# EPOCH [56/100] | Total Loss: 0.027382 | Recon Loss: 0.001969 | Lie Loss: 0.070201 | Prediction Loss: 0.007808 | KL Loss: 0.002998
# TEST  [56/100] | Total Loss: 0.026589 | Recon Loss: 0.001968 | Lie Loss: 0.066952 | Prediction Loss: 0.008990 | KL Loss: 0.002665
# --------------------------------------------------------------------------------------------------------------
# EPOCH [57/100] | Total Loss: 0.025439 | Recon Loss: 0.001906 | Lie Loss: 0.064612 | Prediction Loss: 0.007614 | KL Loss: 0.002957
# TEST  [57/100] | Total Loss: 0.024555 | Recon Loss: 0.001853 | Lie Loss: 0.061921 | Prediction Loss: 0.007116 | KL Loss: 0.003519
# --------------------------------------------------------------------------------------------------------------
# EPOCH [58/100] | Total Loss: 0.023495 | Recon Loss: 0.001819 | Lie Loss: 0.059688 | Prediction Loss: 0.007102 | KL Loss: 0.002589
# TEST  [58/100] | Total Loss: 0.022431 | Recon Loss: 0.001815 | Lie Loss: 0.057043 | Prediction Loss: 0.006527 | KL Loss: 0.002588
# --------------------------------------------------------------------------------------------------------------
# EPOCH [59/100] | Total Loss: 0.021976 | Recon Loss: 0.001760 | Lie Loss: 0.055271 | Prediction Loss: 0.006901 | KL Loss: 0.002660
# TEST  [59/100] | Total Loss: 0.020975 | Recon Loss: 0.001735 | Lie Loss: 0.052818 | Prediction Loss: 0.006677 | KL Loss: 0.002330
# --------------------------------------------------------------------------------------------------------------
# EPOCH [60/100] | Total Loss: 0.020714 | Recon Loss: 0.001713 | Lie Loss: 0.051141 | Prediction Loss: 0.007289 | KL Loss: 0.002629
# TEST  [60/100] | Total Loss: 0.019927 | Recon Loss: 0.001688 | Lie Loss: 0.049012 | Prediction Loss: 0.007170 | KL Loss: 0.002516
# --------------------------------------------------------------------------------------------------------------
# EPOCH [61/100] | Total Loss: 0.019266 | Recon Loss: 0.001649 | Lie Loss: 0.047495 | Prediction Loss: 0.006653 | KL Loss: 0.002585
# TEST  [61/100] | Total Loss: 0.019106 | Recon Loss: 0.001733 | Lie Loss: 0.045490 | Prediction Loss: 0.008151 | KL Loss: 0.002523
# --------------------------------------------------------------------------------------------------------------
# EPOCH [62/100] | Total Loss: 0.018216 | Recon Loss: 0.001614 | Lie Loss: 0.044125 | Prediction Loss: 0.006833 | KL Loss: 0.002627
# TEST  [62/100] | Total Loss: 0.017221 | Recon Loss: 0.001571 | Lie Loss: 0.042269 | Prediction Loss: 0.006057 | KL Loss: 0.002286
# --------------------------------------------------------------------------------------------------------------
# EPOCH [63/100] | Total Loss: 0.017045 | Recon Loss: 0.001561 | Lie Loss: 0.041090 | Prediction Loss: 0.006966 | KL Loss: 0.002036
# TEST  [63/100] | Total Loss: 0.016558 | Recon Loss: 0.001524 | Lie Loss: 0.039460 | Prediction Loss: 0.006923 | KL Loss: 0.002270
# --------------------------------------------------------------------------------------------------------------
# EPOCH [64/100] | Total Loss: 0.016126 | Recon Loss: 0.001515 | Lie Loss: 0.038378 | Prediction Loss: 0.006383 | KL Loss: 0.002591
# TEST  [64/100] | Total Loss: 0.015480 | Recon Loss: 0.001496 | Lie Loss: 0.036962 | Prediction Loss: 0.006059 | KL Loss: 0.002393
# --------------------------------------------------------------------------------------------------------------
# EPOCH [65/100] | Total Loss: 0.015044 | Recon Loss: 0.001474 | Lie Loss: 0.035871 | Prediction Loss: 0.006056 | KL Loss: 0.002187
# TEST  [65/100] | Total Loss: 0.014784 | Recon Loss: 0.001634 | Lie Loss: 0.034511 | Prediction Loss: 0.006536 | KL Loss: 0.002119
# --------------------------------------------------------------------------------------------------------------
# EPOCH [66/100] | Total Loss: 0.014442 | Recon Loss: 0.001447 | Lie Loss: 0.033513 | Prediction Loss: 0.006647 | KL Loss: 0.002157
# TEST  [66/100] | Total Loss: 0.014207 | Recon Loss: 0.001409 | Lie Loss: 0.032372 | Prediction Loss: 0.006193 | KL Loss: 0.003079
# --------------------------------------------------------------------------------------------------------------
# EPOCH [67/100] | Total Loss: 0.013658 | Recon Loss: 0.001405 | Lie Loss: 0.031452 | Prediction Loss: 0.006295 | KL Loss: 0.002236
# TEST  [67/100] | Total Loss: 0.012840 | Recon Loss: 0.001411 | Lie Loss: 0.030349 | Prediction Loss: 0.005352 | KL Loss: 0.001797
# --------------------------------------------------------------------------------------------------------------
# EPOCH [68/100] | Total Loss: 0.013014 | Recon Loss: 0.001366 | Lie Loss: 0.029549 | Prediction Loss: 0.006392 | KL Loss: 0.002130
# TEST  [68/100] | Total Loss: 0.012319 | Recon Loss: 0.001337 | Lie Loss: 0.028556 | Prediction Loss: 0.005322 | KL Loss: 0.002115
# --------------------------------------------------------------------------------------------------------------
# EPOCH [69/100] | Total Loss: 0.012184 | Recon Loss: 0.001328 | Lie Loss: 0.027773 | Prediction Loss: 0.005637 | KL Loss: 0.002183
# TEST  [69/100] | Total Loss: 0.011692 | Recon Loss: 0.001314 | Lie Loss: 0.026895 | Prediction Loss: 0.005370 | KL Loss: 0.001851
# --------------------------------------------------------------------------------------------------------------
# EPOCH [70/100] | Total Loss: 0.011542 | Recon Loss: 0.001303 | Lie Loss: 0.026145 | Prediction Loss: 0.005584 | KL Loss: 0.001944
# TEST  [70/100] | Total Loss: 0.011130 | Recon Loss: 0.001278 | Lie Loss: 0.025280 | Prediction Loss: 0.005234 | KL Loss: 0.001936
# --------------------------------------------------------------------------------------------------------------
# EPOCH [71/100] | Total Loss: 0.011233 | Recon Loss: 0.001271 | Lie Loss: 0.024634 | Prediction Loss: 0.005940 | KL Loss: 0.002195
# TEST  [71/100] | Total Loss: 0.011510 | Recon Loss: 0.001279 | Lie Loss: 0.023804 | Prediction Loss: 0.007868 | KL Loss: 0.001926
# --------------------------------------------------------------------------------------------------------------
# EPOCH [72/100] | Total Loss: 0.010730 | Recon Loss: 0.001262 | Lie Loss: 0.023270 | Prediction Loss: 0.006178 | KL Loss: 0.001807
# TEST  [72/100] | Total Loss: 0.010329 | Recon Loss: 0.001229 | Lie Loss: 0.022528 | Prediction Loss: 0.005169 | KL Loss: 0.002374
# --------------------------------------------------------------------------------------------------------------
# EPOCH [73/100] | Total Loss: 0.010110 | Recon Loss: 0.001230 | Lie Loss: 0.022011 | Prediction Loss: 0.005614 | KL Loss: 0.001782
# TEST  [73/100] | Total Loss: 0.011154 | Recon Loss: 0.001222 | Lie Loss: 0.021322 | Prediction Loss: 0.009206 | KL Loss: 0.002051
# --------------------------------------------------------------------------------------------------------------
# EPOCH [74/100] | Total Loss: 0.009666 | Recon Loss: 0.001222 | Lie Loss: 0.020847 | Prediction Loss: 0.005461 | KL Loss: 0.001760
# TEST  [74/100] | Total Loss: 0.009443 | Recon Loss: 0.001186 | Lie Loss: 0.020242 | Prediction Loss: 0.005280 | KL Loss: 0.001908
# --------------------------------------------------------------------------------------------------------------
# EPOCH [75/100] | Total Loss: 0.009485 | Recon Loss: 0.001199 | Lie Loss: 0.019784 | Prediction Loss: 0.005576 | KL Loss: 0.002183
# TEST  [75/100] | Total Loss: 0.010364 | Recon Loss: 0.001292 | Lie Loss: 0.019138 | Prediction Loss: 0.008123 | KL Loss: 0.002853
# --------------------------------------------------------------------------------------------------------------
# EPOCH [76/100] | Total Loss: 0.009125 | Recon Loss: 0.001182 | Lie Loss: 0.018809 | Prediction Loss: 0.005799 | KL Loss: 0.001863
# TEST  [76/100] | Total Loss: 0.008408 | Recon Loss: 0.001159 | Lie Loss: 0.018254 | Prediction Loss: 0.004739 | KL Loss: 0.001326
# --------------------------------------------------------------------------------------------------------------
# EPOCH [77/100] | Total Loss: 0.008559 | Recon Loss: 0.001155 | Lie Loss: 0.017902 | Prediction Loss: 0.005070 | KL Loss: 0.001808
# TEST  [77/100] | Total Loss: 0.008270 | Recon Loss: 0.001145 | Lie Loss: 0.017442 | Prediction Loss: 0.004609 | KL Loss: 0.001864
# --------------------------------------------------------------------------------------------------------------
# EPOCH [78/100] | Total Loss: 0.008324 | Recon Loss: 0.001149 | Lie Loss: 0.017052 | Prediction Loss: 0.005411 | KL Loss: 0.001612
# TEST  [78/100] | Total Loss: 0.008272 | Recon Loss: 0.001145 | Lie Loss: 0.016580 | Prediction Loss: 0.005960 | KL Loss: 0.001382
# --------------------------------------------------------------------------------------------------------------
# EPOCH [79/100] | Total Loss: 0.008139 | Recon Loss: 0.001132 | Lie Loss: 0.016281 | Prediction Loss: 0.005513 | KL Loss: 0.001739
# TEST  [79/100] | Total Loss: 0.007747 | Recon Loss: 0.001121 | Lie Loss: 0.015912 | Prediction Loss: 0.004516 | KL Loss: 0.001928
# --------------------------------------------------------------------------------------------------------------
# EPOCH [80/100] | Total Loss: 0.007741 | Recon Loss: 0.001126 | Lie Loss: 0.015562 | Prediction Loss: 0.004948 | KL Loss: 0.001822
# TEST  [80/100] | Total Loss: 0.007531 | Recon Loss: 0.001110 | Lie Loss: 0.015180 | Prediction Loss: 0.004851 | KL Loss: 0.001681
# --------------------------------------------------------------------------------------------------------------
# EPOCH [81/100] | Total Loss: 0.007642 | Recon Loss: 0.001118 | Lie Loss: 0.014896 | Prediction Loss: 0.005451 | KL Loss: 0.001693
# TEST  [81/100] | Total Loss: 0.007131 | Recon Loss: 0.001111 | Lie Loss: 0.014543 | Prediction Loss: 0.004403 | KL Loss: 0.001553
# --------------------------------------------------------------------------------------------------------------
# EPOCH [82/100] | Total Loss: 0.007230 | Recon Loss: 0.001100 | Lie Loss: 0.014291 | Prediction Loss: 0.004883 | KL Loss: 0.001635
# TEST  [82/100] | Total Loss: 0.007267 | Recon Loss: 0.001115 | Lie Loss: 0.013993 | Prediction Loss: 0.005337 | KL Loss: 0.001576
# --------------------------------------------------------------------------------------------------------------
# EPOCH [83/100] | Total Loss: 0.007216 | Recon Loss: 0.001093 | Lie Loss: 0.013718 | Prediction Loss: 0.005176 | KL Loss: 0.001880
# TEST  [83/100] | Total Loss: 0.006786 | Recon Loss: 0.001077 | Lie Loss: 0.013381 | Prediction Loss: 0.004482 | KL Loss: 0.001623
# --------------------------------------------------------------------------------------------------------------
# EPOCH [84/100] | Total Loss: 0.007098 | Recon Loss: 0.001089 | Lie Loss: 0.013202 | Prediction Loss: 0.005431 | KL Loss: 0.001786
# TEST  [84/100] | Total Loss: 0.006491 | Recon Loss: 0.001071 | Lie Loss: 0.012949 | Prediction Loss: 0.004252 | KL Loss: 0.001398
# --------------------------------------------------------------------------------------------------------------
# EPOCH [85/100] | Total Loss: 0.006511 | Recon Loss: 0.001075 | Lie Loss: 0.012715 | Prediction Loss: 0.004536 | KL Loss: 0.001405
# TEST  [85/100] | Total Loss: 0.006705 | Recon Loss: 0.001078 | Lie Loss: 0.012455 | Prediction Loss: 0.005242 | KL Loss: 0.001543
# --------------------------------------------------------------------------------------------------------------
# EPOCH [86/100] | Total Loss: 0.006588 | Recon Loss: 0.001071 | Lie Loss: 0.012258 | Prediction Loss: 0.004879 | KL Loss: 0.001755
# TEST  [86/100] | Total Loss: 0.006347 | Recon Loss: 0.001051 | Lie Loss: 0.012002 | Prediction Loss: 0.004951 | KL Loss: 0.001229
# --------------------------------------------------------------------------------------------------------------
# EPOCH [87/100] | Total Loss: 0.006211 | Recon Loss: 0.001056 | Lie Loss: 0.011836 | Prediction Loss: 0.004579 | KL Loss: 0.001351
# TEST  [87/100] | Total Loss: 0.005893 | Recon Loss: 0.001055 | Lie Loss: 0.011612 | Prediction Loss: 0.004074 | KL Loss: 0.001117
# --------------------------------------------------------------------------------------------------------------
# EPOCH [88/100] | Total Loss: 0.006272 | Recon Loss: 0.001054 | Lie Loss: 0.011446 | Prediction Loss: 0.005091 | KL Loss: 0.001414
# TEST  [88/100] | Total Loss: 0.005954 | Recon Loss: 0.001035 | Lie Loss: 0.011240 | Prediction Loss: 0.004088 | KL Loss: 0.001681
# --------------------------------------------------------------------------------------------------------------
# EPOCH [89/100] | Total Loss: 0.006131 | Recon Loss: 0.001044 | Lie Loss: 0.011088 | Prediction Loss: 0.004753 | KL Loss: 0.001692
# TEST  [89/100] | Total Loss: 0.006015 | Recon Loss: 0.001033 | Lie Loss: 0.010929 | Prediction Loss: 0.005117 | KL Loss: 0.001147
# --------------------------------------------------------------------------------------------------------------
# EPOCH [90/100] | Total Loss: 0.005823 | Recon Loss: 0.001043 | Lie Loss: 0.010751 | Prediction Loss: 0.004315 | KL Loss: 0.001536
# TEST  [90/100] | Total Loss: 0.005650 | Recon Loss: 0.001055 | Lie Loss: 0.010557 | Prediction Loss: 0.003940 | KL Loss: 0.001570
# --------------------------------------------------------------------------------------------------------------
# EPOCH [91/100] | Total Loss: 0.005780 | Recon Loss: 0.001032 | Lie Loss: 0.010419 | Prediction Loss: 0.004583 | KL Loss: 0.001483
# TEST  [91/100] | Total Loss: 0.005643 | Recon Loss: 0.001025 | Lie Loss: 0.010288 | Prediction Loss: 0.003957 | KL Loss: 0.001832
# --------------------------------------------------------------------------------------------------------------
# EPOCH [92/100] | Total Loss: 0.005670 | Recon Loss: 0.001028 | Lie Loss: 0.010122 | Prediction Loss: 0.004591 | KL Loss: 0.001440
# TEST  [92/100] | Total Loss: 0.005954 | Recon Loss: 0.001037 | Lie Loss: 0.009983 | Prediction Loss: 0.005505 | KL Loss: 0.001518
# --------------------------------------------------------------------------------------------------------------
# EPOCH [93/100] | Total Loss: 0.005522 | Recon Loss: 0.001025 | Lie Loss: 0.009847 | Prediction Loss: 0.004515 | KL Loss: 0.001345
# TEST  [93/100] | Total Loss: 0.005408 | Recon Loss: 0.001012 | Lie Loss: 0.009686 | Prediction Loss: 0.003785 | KL Loss: 0.001904
# --------------------------------------------------------------------------------------------------------------
# EPOCH [94/100] | Total Loss: 0.005314 | Recon Loss: 0.001018 | Lie Loss: 0.009586 | Prediction Loss: 0.004225 | KL Loss: 0.001276
# TEST  [94/100] | Total Loss: 0.005348 | Recon Loss: 0.000994 | Lie Loss: 0.009457 | Prediction Loss: 0.004519 | KL Loss: 0.001237
# --------------------------------------------------------------------------------------------------------------
# EPOCH [95/100] | Total Loss: 0.005499 | Recon Loss: 0.001015 | Lie Loss: 0.009355 | Prediction Loss: 0.005003 | KL Loss: 0.001292
# TEST  [95/100] | Total Loss: 0.005178 | Recon Loss: 0.000995 | Lie Loss: 0.009221 | Prediction Loss: 0.003712 | KL Loss: 0.001763
# --------------------------------------------------------------------------------------------------------------
# EPOCH [96/100] | Total Loss: 0.005216 | Recon Loss: 0.001009 | Lie Loss: 0.009124 | Prediction Loss: 0.004305 | KL Loss: 0.001367
# TEST  [96/100] | Total Loss: 0.004996 | Recon Loss: 0.000997 | Lie Loss: 0.009038 | Prediction Loss: 0.003650 | KL Loss: 0.001454
# --------------------------------------------------------------------------------------------------------------
# EPOCH [97/100] | Total Loss: 0.005052 | Recon Loss: 0.001001 | Lie Loss: 0.008913 | Prediction Loss: 0.003919 | KL Loss: 0.001477
# TEST  [97/100] | Total Loss: 0.004901 | Recon Loss: 0.000998 | Lie Loss: 0.008809 | Prediction Loss: 0.003684 | KL Loss: 0.001359
# --------------------------------------------------------------------------------------------------------------
# EPOCH [98/100] | Total Loss: 0.005257 | Recon Loss: 0.000993 | Lie Loss: 0.008709 | Prediction Loss: 0.004693 | KL Loss: 0.001535
# TEST  [98/100] | Total Loss: 0.004961 | Recon Loss: 0.001004 | Lie Loss: 0.008622 | Prediction Loss: 0.004410 | KL Loss: 0.000997
# --------------------------------------------------------------------------------------------------------------
# EPOCH [99/100] | Total Loss: 0.004965 | Recon Loss: 0.000999 | Lie Loss: 0.008523 | Prediction Loss: 0.004192 | KL Loss: 0.001331
# TEST  [99/100] | Total Loss: 0.004778 | Recon Loss: 0.000985 | Lie Loss: 0.008422 | Prediction Loss: 0.003775 | KL Loss: 0.001297
# --------------------------------------------------------------------------------------------------------------
# EPOCH [100/100] | Total Loss: 0.004877 | Recon Loss: 0.000982 | Lie Loss: 0.008337 | Prediction Loss: 0.004176 | KL Loss: 0.001285
# TEST  [100/100] | Total Loss: 0.004806 | Recon Loss: 0.000995 | Lie Loss: 0.008270 | Prediction Loss: 0.003854 | KL Loss: 0.001445
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Verification

# %% [markdown]
# **Question 6.** : As in the **Question 3.** we want to ensure the Lie operator is stable. This can be verified by checking that the real part of the eigenvalues is negative. Plot the relevant eigenvalues of the Lie operator. You can use the [`numpy.linalg.eig`](https://numpy.org/doc/stable/reference/generated/numpy.linalg.eig.html) function to retrieve the eigenvalues of a matrix.

# %%
# TODO: Check the eigenvalues real part
eigenval, _ = np.linalg.eig(lie_matrix.cpu().detach().numpy())
print(max(np.real(eigenval)))
# Out:
# -0.035815436

# %%
# TODO: Plot the eigenvalues
fig, ax = plt.subplots(figsize=(10, 5))

ax.bar(np.arange(len(eigenval)), eigenval, width = 0.2, color='b')
ax.axhline(y=1, linestyle='--', color ='r')
ax.axhline(y=-1, linestyle='--', color ='r')
ax.set_xticks(ticks=np.arange(len(eigenval)))
ax.set_ylabel('$\lambda$')

plt.title('Eigenvalues')
plt.show()
# Out:
# /home/carlos/.local/lib/python3.10/site-packages/matplotlib/transforms.py:762: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.asarray(points, float)

# %%
n_grid = 30
x1_min, x1_max = -2, 2
x2_min, x2_max = -2, 2
array_x1 = np.linspace(x1_min, x1_max, n_grid, dtype=np.float32)
array_x2 = np.linspace(x2_min, x2_max, n_grid, dtype=np.float32)
matrix_grid_x1, matrix_grid_x2 = np.meshgrid(array_x1, array_x2)

array3d_dynamics = np.zeros((n_grid, n_grid, 2))

for i in range(n_grid):
    for j in range(n_grid):
        array3d_dynamics[i, j, :] = duffing(np.array([matrix_grid_x1[i, j], matrix_grid_x2[i, j]]))

autoencoder.eval()
lie_operator.eval()
array3d_dynamics_pred = np.zeros((n_grid, n_grid, 2))
for i in range(n_grid):
    for j in range(n_grid):
        x1 = matrix_grid_x1[i, j]
        x2 = matrix_grid_x2[i, j]
        tensor2d_x = torch.tensor([[x1, x2]], dtype=torch.float32).to(device)
        tensor2d_observable = autoencoder.encoder(tensor2d_x)
        tensor2d_lie_observable_next, _ = lie_operator(tensor2d_observable)
        tensor2d_predict_x_next = autoencoder.decoder(tensor2d_lie_observable_next)
        array_x_next = tensor2d_predict_x_next.cpu().detach().numpy().ravel()

        array3d_dynamics_pred[i, j, :] = array_x_next

# %%
fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(131)
ax.quiver(matrix_grid_x1, matrix_grid_x2, array3d_dynamics[:, :, 0], array3d_dynamics[:, :, 1], scale=10)
ax.set_title('True')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')

ax = fig.add_subplot(132)
ax.quiver(matrix_grid_x1, matrix_grid_x2, array3d_dynamics_pred[:, :, 0], array3d_dynamics_pred[:, :, 1], scale=10)
ax.set_title('Prediction')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')

ax = fig.add_subplot(133)
cp = ax.contourf(matrix_grid_x1, matrix_grid_x2,
                 np.log(np.linalg.norm(array3d_dynamics - array3d_dynamics_pred, axis=2)))
fig.colorbar(cp)
ax.set_title('Error in log scale')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')

plt.show()

# %% [markdown]
# **Question 7.** : Compare and comment below the two approaches (discrete vs continuous operator).

# %% [markdown]
# As we did for the discrete case, we tried for the uniform configuration over the loss parameters. We decided to keep this combination of values as they reported very good results.
#
# **Comparisson between discrete and continuous approaches:**
#
# We found two main differences in the results obtained for the two cases. On the first hand, we can notice that the losses convergence is slower for the continuous case. However, the results obtained in terms of the log error are better for the continuous case, as we can see in the heatmap. This increase in performance is also visible in the quality of the reproduction of the original system.

# %% [markdown]
# **-- PLEASE SUBMIT YOUR COMPLETED NOTEBOOK WITH CELL OUTPUTS --**
